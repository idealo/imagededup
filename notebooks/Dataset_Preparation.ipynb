# %%
# Generate a dataset with transformations agreed upon after survey
# 1. Rotate (25 degrees) (25 degrees selected to keep in line with the image-tagging project)
# 2. Horizontal flip
# 3. Resize to (300, 300) [This modifies the aspect ratio to 1:1]
# 4. Crop images while preserving the aspect ratio (all images cropped to same size, but crops have different parts of
# the image). Selected size= (560, 420). Preserves the aspect ratio. Keeps 87.5% of the size (same as image-tagging)
# 5. Vertical flip

# Naming: Take each image, apply transformations and name: <original_name>_<transformation_name>.jpg

# %%
# paths

import os
import pdb
import pickle
import itertools
import numpy as np

from pathlib import Path
from PIL import Image
from shutil import copyfile

path_source = Path('ukbench/full/')

# %% [markdown]
# # Transformed Dataset

# %%
path_target_query = Path('Transformed_dataset/Query')
path_target_retrieval = Path('Transformed_dataset/Retrieval')

if not os.path.exists(path_target_query):
    os.makedirs(path_target_query)
if not os.path.exists(path_target_retrieval):
    os.makedirs(path_target_retrieval)

# %%
dict_ground_truth = {}

# %%
all_near_dups = sorted(os.listdir(path_source))
n_groups = 2550 # Total number of groups in the dataset (complete dataset has 2550 groups for a total of 10,200 images)
splitted_groups = np.array_split(all_near_dups, n_groups)

# %%
def save_func(transformed_image, target_dir, orig_name, transform_name):
    save_name = os.path.join(target_dir, orig_name + '_' + transform_name + '.jpg')
    transformed_image.save(save_name)
    return save_name

# %%
def rot_func(opened_image, image_name, theta=25):
    rot_im = opened_image.rotate(theta)
    save_name = save_func(rot_im, path_target_retrieval.absolute(), image_name.split('/')[2].split('.')[0], 'rotation')
    # pdb.set_trace()
    save_name = save_name.split('/')[-1]
    return save_name

# %%
def hflip_func(opened_image, image_name):
    hflip_im = opened_image.transpose(method=Image.FLIP_LEFT_RIGHT)
    save_name = save_func(hflip_im, path_target_retrieval.absolute(), image_name.split('/')[2].split('.')[0], 'hflip')
    save_name = save_name.split('/')[-1]
    return save_name

# %%
def resize_func(opened_image, image_name, target_size=(300,300)):
    res_im = opened_image.resize(target_size)
    save_name = save_func(res_im, path_target_retrieval.absolute(), image_name.split('/')[2].split('.')[0], 'resize')
    save_name = save_name.split('/')[-1]
    return save_name

# %%
def vflip_func(opened_image, image_name):
    vflip_im = opened_image.transpose(method=Image.FLIP_TOP_BOTTOM)
    save_name = save_func(vflip_im, path_target_retrieval.absolute(), image_name.split('/')[2].split('.')[0], 'vflip')
    save_name = save_name.split('/')[-1]
    return save_name

# %%
def random_crop_func(opened_image, image_name, crop_dims=(560, 420)):
    h, w = opened_image.height, opened_image.width # h=480, w=640
    ch, cw = crop_dims[1], crop_dims[0] # ch=420, cw=560
    
    left = np.random.randint(0, w - cw)
    right = left + cw
    upper = np.random.randint(0, h - ch)
    lower = upper + ch
    
    box = (left, upper, right, lower)
    
    cropped_im = opened_image.crop(box)
    save_name = save_func(cropped_im, path_target_retrieval.absolute(), image_name.split('/')[2].split('.')[0], 'cropped')
    save_name = save_name.split('/')[-1]
    return save_name

# %%
# get one candidate from each group

# %%
for j in splitted_groups:
    # generate random number between 0 and 3 (inclusive) to select candidate as query image
    index_to_select = np.random.randint(0, 4)
    i = j[index_to_select]
    
    image_name = os.path.join(path_source, i)
    im = Image.open(image_name)
    
    # save transformed images
    save_name_rot = rot_func(im, image_name)
    save_name_hflip = hflip_func(im, image_name)
    save_name_res = resize_func(im, image_name)
    save_name_vflip = vflip_func(im, image_name)
    save_name_crop = random_crop_func(im, image_name)
    key_name = i # image_name.split('/')[1]
    dict_ground_truth[key_name] = [save_name_rot, save_name_hflip, save_name_res, save_name_crop, save_name_vflip]
    
    # save query images
    im.save(os.path.join(path_target_query, i))
    # break

# %%
dict_ground_truth
# Out:
# {'ukbench00002.jpg': ['ukbench00002_rotation.jpg',
#   'ukbench00002_hflip.jpg',
#   'ukbench00002_resize.jpg',
#   'ukbench00002_cropped.jpg',
#   'ukbench00002_vflip.jpg'],
#  'ukbench00005.jpg': ['ukbench00005_rotation.jpg',
#   'ukbench00005_hflip.jpg',
#   'ukbench00005_resize.jpg',
#   'ukbench00005_cropped.jpg',
#   'ukbench00005_vflip.jpg'],
#  'ukbench00009.jpg': ['ukbench00009_rotation.jpg',
#   'ukbench00009_hflip.jpg',
#   'ukbench00009_resize.jpg',
#   'ukbench00009_cropped.jpg',
#   'ukbench00009_vflip.jpg'],
#  'ukbench00013.jpg': ['ukbench00013_rotation.jpg',
#   'ukbench00013_hflip.jpg',
#   'ukbench00013_resize.jpg',
#   'ukbench00013_cropped.jpg',
#   'ukbench00013_vflip.jpg'],
#  'ukbench00017.jpg': ['ukbench00017_rotation.jpg',
#   'ukbench00017_hflip.jpg',
#   'ukbench00017_resize.jpg',
#   'ukbench00017_cropped.jpg',
#   'ukbench00017_vflip.jpg'],
#  'ukbench00023.jpg': ['ukbench00023_rotation.jpg',
#   'ukbench00023_hflip.jpg',
#   'ukbench00023_resize.jpg',
#   'ukbench00023_cropped.jpg',
#   'ukbench00023_vflip.jpg'],
#  'ukbench00027.jpg': ['ukbench00027_rotation.jpg',
#   'ukbench00027_hflip.jpg',
#   'ukbench00027_resize.jpg',
#   'ukbench00027_cropped.jpg',
#   'ukbench00027_vflip.jpg'],
#  'ukbench00029.jpg': ['ukbench00029_rotation.jpg',
#   'ukbench00029_hflip.jpg',
#   'ukbench00029_resize.jpg',
#   'ukbench00029_cropped.jpg',
#   'ukbench00029_vflip.jpg'],
#  'ukbench00033.jpg': ['ukbench00033_rotation.jpg',
#   'ukbench00033_hflip.jpg',
#   'ukbench00033_resize.jpg',
#   'ukbench00033_cropped.jpg',
#   'ukbench00033_vflip.jpg'],
#  'ukbench00036.jpg': ['ukbench00036_rotation.jpg',
#   'ukbench00036_hflip.jpg',
#   'ukbench00036_resize.jpg',
#   'ukbench00036_cropped.jpg',
#   'ukbench00036_vflip.jpg'],
#  'ukbench00040.jpg': ['ukbench00040_rotation.jpg',
#   'ukbench00040_hflip.jpg',
#   'ukbench00040_resize.jpg',
#   'ukbench00040_cropped.jpg',
#   'ukbench00040_vflip.jpg'],
#  'ukbench00045.jpg': ['ukbench00045_rotation.jpg',
#   'ukbench00045_hflip.jpg',
#   'ukbench00045_resize.jpg',
#   'ukbench00045_cropped.jpg',
#   'ukbench00045_vflip.jpg'],
#  'ukbench00048.jpg': ['ukbench00048_rotation.jpg',
#   'ukbench00048_hflip.jpg',
#   'ukbench00048_resize.jpg',
#   'ukbench00048_cropped.jpg',
#   'ukbench00048_vflip.jpg'],
#  'ukbench00054.jpg': ['ukbench00054_rotation.jpg',
#   'ukbench00054_hflip.jpg',
#   'ukbench00054_resize.jpg',
#   'ukbench00054_cropped.jpg',
#   'ukbench00054_vflip.jpg'],
#  'ukbench00058.jpg': ['ukbench00058_rotation.jpg',
#   'ukbench00058_hflip.jpg',
#   'ukbench00058_resize.jpg',
#   'ukbench00058_cropped.jpg',
#   'ukbench00058_vflip.jpg'],
#  'ukbench00062.jpg': ['ukbench00062_rotation.jpg',
#   'ukbench00062_hflip.jpg',
#   'ukbench00062_resize.jpg',
#   'ukbench00062_cropped.jpg',
#   'ukbench00062_vflip.jpg'],
#  'ukbench00065.jpg': ['ukbench00065_rotation.jpg',
#   'ukbench00065_hflip.jpg',
#   'ukbench00065_resize.jpg',
#   'ukbench00065_cropped.jpg',
#   'ukbench00065_vflip.jpg'],
#  'ukbench00069.jpg': ['ukbench00069_rotation.jpg',
#   'ukbench00069_hflip.jpg',
#   'ukbench00069_resize.jpg',
#   'ukbench00069_cropped.jpg',
#   'ukbench00069_vflip.jpg'],
#  'ukbench00074.jpg': ['ukbench00074_rotation.jpg',
#   'ukbench00074_hflip.jpg',
#   'ukbench00074_resize.jpg',
#   'ukbench00074_cropped.jpg',
#   'ukbench00074_vflip.jpg'],
#  'ukbench00076.jpg': ['ukbench00076_rotation.jpg',
#   'ukbench00076_hflip.jpg',
#   'ukbench00076_resize.jpg',
#   'ukbench00076_cropped.jpg',
#   'ukbench00076_vflip.jpg'],
#  'ukbench00083.jpg': ['ukbench00083_rotation.jpg',
#   'ukbench00083_hflip.jpg',
#   'ukbench00083_resize.jpg',
#   'ukbench00083_cropped.jpg',
#   'ukbench00083_vflip.jpg'],
#  'ukbench00085.jpg': ['ukbench00085_rotation.jpg',
#   'ukbench00085_hflip.jpg',
#   'ukbench00085_resize.jpg',
#   'ukbench00085_cropped.jpg',
#   'ukbench00085_vflip.jpg'],
#  'ukbench00088.jpg': ['ukbench00088_rotation.jpg',
#   'ukbench00088_hflip.jpg',
#   'ukbench00088_resize.jpg',
#   'ukbench00088_cropped.jpg',
#   'ukbench00088_vflip.jpg'],
#  'ukbench00094.jpg': ['ukbench00094_rotation.jpg',
#   'ukbench00094_hflip.jpg',
#   'ukbench00094_resize.jpg',
#   'ukbench00094_cropped.jpg',
#   'ukbench00094_vflip.jpg'],
#  'ukbench00099.jpg': ['ukbench00099_rotation.jpg',
#   'ukbench00099_hflip.jpg',
#   'ukbench00099_resize.jpg',
#   'ukbench00099_cropped.jpg',
#   'ukbench00099_vflip.jpg'],
#  'ukbench00102.jpg': ['ukbench00102_rotation.jpg',
#   'ukbench00102_hflip.jpg',
#   'ukbench00102_resize.jpg',
#   'ukbench00102_cropped.jpg',
#   'ukbench00102_vflip.jpg'],
#  'ukbench00105.jpg': ['ukbench00105_rotation.jpg',
#   'ukbench00105_hflip.jpg',
#   'ukbench00105_resize.jpg',
#   'ukbench00105_cropped.jpg',
#   'ukbench00105_vflip.jpg'],
#  'ukbench00108.jpg': ['ukbench00108_rotation.jpg',
#   'ukbench00108_hflip.jpg',
#   'ukbench00108_resize.jpg',
#   'ukbench00108_cropped.jpg',
#   'ukbench00108_vflip.jpg'],
#  'ukbench00114.jpg': ['ukbench00114_rotation.jpg',
#   'ukbench00114_hflip.jpg',
#   'ukbench00114_resize.jpg',
#   'ukbench00114_cropped.jpg',
#   'ukbench00114_vflip.jpg'],
#  'ukbench00118.jpg': ['ukbench00118_rotation.jpg',
#   'ukbench00118_hflip.jpg',
#   'ukbench00118_resize.jpg',
#   'ukbench00118_cropped.jpg',
#   'ukbench00118_vflip.jpg'],
#  'ukbench00123.jpg': ['ukbench00123_rotation.jpg',
#   'ukbench00123_hflip.jpg',
#   'ukbench00123_resize.jpg',
#   'ukbench00123_cropped.jpg',
#   'ukbench00123_vflip.jpg'],
#  'ukbench00127.jpg': ['ukbench00127_rotation.jpg',
#   'ukbench00127_hflip.jpg',
#   'ukbench00127_resize.jpg',
#   'ukbench00127_cropped.jpg',
#   'ukbench00127_vflip.jpg'],
#  'ukbench00129.jpg': ['ukbench00129_rotation.jpg',
#   'ukbench00129_hflip.jpg',
#   'ukbench00129_resize.jpg',
#   'ukbench00129_cropped.jpg',
#   'ukbench00129_vflip.jpg'],
#  'ukbench00132.jpg': ['ukbench00132_rotation.jpg',
#   'ukbench00132_hflip.jpg',
#   'ukbench00132_resize.jpg',
#   'ukbench00132_cropped.jpg',
#   'ukbench00132_vflip.jpg'],
#  'ukbench00139.jpg': ['ukbench00139_rotation.jpg',
#   'ukbench00139_hflip.jpg',
#   'ukbench00139_resize.jpg',
#   'ukbench00139_cropped.jpg',
#   'ukbench00139_vflip.jpg'],
#  'ukbench00142.jpg': ['ukbench00142_rotation.jpg',
#   'ukbench00142_hflip.jpg',
#   'ukbench00142_resize.jpg',
#   'ukbench00142_cropped.jpg',
#   'ukbench00142_vflip.jpg'],
#  'ukbench00147.jpg': ['ukbench00147_rotation.jpg',
#   'ukbench00147_hflip.jpg',
#   'ukbench00147_resize.jpg',
#   'ukbench00147_cropped.jpg',
#   'ukbench00147_vflip.jpg'],
#  'ukbench00149.jpg': ['ukbench00149_rotation.jpg',
#   'ukbench00149_hflip.jpg',
#   'ukbench00149_resize.jpg',
#   'ukbench00149_cropped.jpg',
#   'ukbench00149_vflip.jpg'],
#  'ukbench00152.jpg': ['ukbench00152_rotation.jpg',
#   'ukbench00152_hflip.jpg',
#   'ukbench00152_resize.jpg',
#   'ukbench00152_cropped.jpg',
#   'ukbench00152_vflip.jpg'],
#  'ukbench00159.jpg': ['ukbench00159_rotation.jpg',
#   'ukbench00159_hflip.jpg',
#   'ukbench00159_resize.jpg',
#   'ukbench00159_cropped.jpg',
#   'ukbench00159_vflip.jpg'],
#  'ukbench00163.jpg': ['ukbench00163_rotation.jpg',
#   'ukbench00163_hflip.jpg',
#   'ukbench00163_resize.jpg',
#   'ukbench00163_cropped.jpg',
#   'ukbench00163_vflip.jpg'],
#  'ukbench00167.jpg': ['ukbench00167_rotation.jpg',
#   'ukbench00167_hflip.jpg',
#   'ukbench00167_resize.jpg',
#   'ukbench00167_cropped.jpg',
#   'ukbench00167_vflip.jpg'],
#  'ukbench00171.jpg': ['ukbench00171_rotation.jpg',
#   'ukbench00171_hflip.jpg',
#   'ukbench00171_resize.jpg',
#   'ukbench00171_cropped.jpg',
#   'ukbench00171_vflip.jpg'],
#  'ukbench00173.jpg': ['ukbench00173_rotation.jpg',
#   'ukbench00173_hflip.jpg',
#   'ukbench00173_resize.jpg',
#   'ukbench00173_cropped.jpg',
#   'ukbench00173_vflip.jpg'],
#  'ukbench00179.jpg': ['ukbench00179_rotation.jpg',
#   'ukbench00179_hflip.jpg',
#   'ukbench00179_resize.jpg',
#   'ukbench00179_cropped.jpg',
#   'ukbench00179_vflip.jpg'],
#  'ukbench00181.jpg': ['ukbench00181_rotation.jpg',
#   'ukbench00181_hflip.jpg',
#   'ukbench00181_resize.jpg',
#   'ukbench00181_cropped.jpg',
#   'ukbench00181_vflip.jpg'],
#  'ukbench00184.jpg': ['ukbench00184_rotation.jpg',
#   'ukbench00184_hflip.jpg',
#   'ukbench00184_resize.jpg',
#   'ukbench00184_cropped.jpg',
#   'ukbench00184_vflip.jpg'],
#  'ukbench00188.jpg': ['ukbench00188_rotation.jpg',
#   'ukbench00188_hflip.jpg',
#   'ukbench00188_resize.jpg',
#   'ukbench00188_cropped.jpg',
#   'ukbench00188_vflip.jpg'],
#  'ukbench00193.jpg': ['ukbench00193_rotation.jpg',
#   'ukbench00193_hflip.jpg',
#   'ukbench00193_resize.jpg',
#   'ukbench00193_cropped.jpg',
#   'ukbench00193_vflip.jpg'],
#  'ukbench00197.jpg': ['ukbench00197_rotation.jpg',
#   'ukbench00197_hflip.jpg',
#   'ukbench00197_resize.jpg',
#   'ukbench00197_cropped.jpg',
#   'ukbench00197_vflip.jpg'],
#  'ukbench00201.jpg': ['ukbench00201_rotation.jpg',
#   'ukbench00201_hflip.jpg',
#   'ukbench00201_resize.jpg',
#   'ukbench00201_cropped.jpg',
#   'ukbench00201_vflip.jpg'],
#  'ukbench00204.jpg': ['ukbench00204_rotation.jpg',
#   'ukbench00204_hflip.jpg',
#   'ukbench00204_resize.jpg',
#   'ukbench00204_cropped.jpg',
#   'ukbench00204_vflip.jpg'],
#  'ukbench00209.jpg': ['ukbench00209_rotation.jpg',
#   'ukbench00209_hflip.jpg',
#   'ukbench00209_resize.jpg',
#   'ukbench00209_cropped.jpg',
#   'ukbench00209_vflip.jpg'],
#  'ukbench00214.jpg': ['ukbench00214_rotation.jpg',
#   'ukbench00214_hflip.jpg',
#   'ukbench00214_resize.jpg',
#   'ukbench00214_cropped.jpg',
#   'ukbench00214_vflip.jpg'],
#  'ukbench00218.jpg': ['ukbench00218_rotation.jpg',
#   'ukbench00218_hflip.jpg',
#   'ukbench00218_resize.jpg',
#   'ukbench00218_cropped.jpg',
#   'ukbench00218_vflip.jpg'],
#  'ukbench00222.jpg': ['ukbench00222_rotation.jpg',
#   'ukbench00222_hflip.jpg',
#   'ukbench00222_resize.jpg',
#   'ukbench00222_cropped.jpg',
#   'ukbench00222_vflip.jpg'],
#  'ukbench00225.jpg': ['ukbench00225_rotation.jpg',
#   'ukbench00225_hflip.jpg',
#   'ukbench00225_resize.jpg',
#   'ukbench00225_cropped.jpg',
#   'ukbench00225_vflip.jpg'],
#  'ukbench00230.jpg': ['ukbench00230_rotation.jpg',
#   'ukbench00230_hflip.jpg',
#   'ukbench00230_resize.jpg',
#   'ukbench00230_cropped.jpg',
#   'ukbench00230_vflip.jpg'],
#  'ukbench00233.jpg': ['ukbench00233_rotation.jpg',
#   'ukbench00233_hflip.jpg',
#   'ukbench00233_resize.jpg',
#   'ukbench00233_cropped.jpg',
#   'ukbench00233_vflip.jpg'],
#  'ukbench00239.jpg': ['ukbench00239_rotation.jpg',
#   'ukbench00239_hflip.jpg',
#   'ukbench00239_resize.jpg',
#   'ukbench00239_cropped.jpg',
#   'ukbench00239_vflip.jpg'],
#  'ukbench00242.jpg': ['ukbench00242_rotation.jpg',
#   'ukbench00242_hflip.jpg',
#   'ukbench00242_resize.jpg',
#   'ukbench00242_cropped.jpg',
#   'ukbench00242_vflip.jpg'],
#  'ukbench00244.jpg': ['ukbench00244_rotation.jpg',
#   'ukbench00244_hflip.jpg',
#   'ukbench00244_resize.jpg',
#   'ukbench00244_cropped.jpg',
#   'ukbench00244_vflip.jpg'],
#  'ukbench00250.jpg': ['ukbench00250_rotation.jpg',
#   'ukbench00250_hflip.jpg',
#   'ukbench00250_resize.jpg',
#   'ukbench00250_cropped.jpg',
#   'ukbench00250_vflip.jpg'],
#  'ukbench00254.jpg': ['ukbench00254_rotation.jpg',
#   'ukbench00254_hflip.jpg',
#   'ukbench00254_resize.jpg',
#   'ukbench00254_cropped.jpg',
#   'ukbench00254_vflip.jpg'],
#  'ukbench00256.jpg': ['ukbench00256_rotation.jpg',
#   'ukbench00256_hflip.jpg',
#   'ukbench00256_resize.jpg',
#   'ukbench00256_cropped.jpg',
#   'ukbench00256_vflip.jpg'],
#  'ukbench00260.jpg': ['ukbench00260_rotation.jpg',
#   'ukbench00260_hflip.jpg',
#   'ukbench00260_resize.jpg',
#   'ukbench00260_cropped.jpg',
#   'ukbench00260_vflip.jpg'],
#  'ukbench00265.jpg': ['ukbench00265_rotation.jpg',
#   'ukbench00265_hflip.jpg',
#   'ukbench00265_resize.jpg',
#   'ukbench00265_cropped.jpg',
#   'ukbench00265_vflip.jpg'],
#  'ukbench00269.jpg': ['ukbench00269_rotation.jpg',
#   'ukbench00269_hflip.jpg',
#   'ukbench00269_resize.jpg',
#   'ukbench00269_cropped.jpg',
#   'ukbench00269_vflip.jpg'],
#  'ukbench00274.jpg': ['ukbench00274_rotation.jpg',
#   'ukbench00274_hflip.jpg',
#   'ukbench00274_resize.jpg',
#   'ukbench00274_cropped.jpg',
#   'ukbench00274_vflip.jpg'],
#  'ukbench00277.jpg': ['ukbench00277_rotation.jpg',
#   'ukbench00277_hflip.jpg',
#   'ukbench00277_resize.jpg',
#   'ukbench00277_cropped.jpg',
#   'ukbench00277_vflip.jpg'],
#  'ukbench00283.jpg': ['ukbench00283_rotation.jpg',
#   'ukbench00283_hflip.jpg',
#   'ukbench00283_resize.jpg',
#   'ukbench00283_cropped.jpg',
#   'ukbench00283_vflip.jpg'],
#  'ukbench00287.jpg': ['ukbench00287_rotation.jpg',
#   'ukbench00287_hflip.jpg',
#   'ukbench00287_resize.jpg',
#   'ukbench00287_cropped.jpg',
#   'ukbench00287_vflip.jpg'],
#  'ukbench00288.jpg': ['ukbench00288_rotation.jpg',
#   'ukbench00288_hflip.jpg',
#   'ukbench00288_resize.jpg',
#   'ukbench00288_cropped.jpg',
#   'ukbench00288_vflip.jpg'],
#  'ukbench00293.jpg': ['ukbench00293_rotation.jpg',
#   'ukbench00293_hflip.jpg',
#   'ukbench00293_resize.jpg',
#   'ukbench00293_cropped.jpg',
#   'ukbench00293_vflip.jpg'],
#  'ukbench00298.jpg': ['ukbench00298_rotation.jpg',
#   'ukbench00298_hflip.jpg',
#   'ukbench00298_resize.jpg',
#   'ukbench00298_cropped.jpg',
#   'ukbench00298_vflip.jpg'],
#  'ukbench00300.jpg': ['ukbench00300_rotation.jpg',
#   'ukbench00300_hflip.jpg',
#   'ukbench00300_resize.jpg',
#   'ukbench00300_cropped.jpg',
#   'ukbench00300_vflip.jpg'],
#  'ukbench00305.jpg': ['ukbench00305_rotation.jpg',
#   'ukbench00305_hflip.jpg',
#   'ukbench00305_resize.jpg',
#   'ukbench00305_cropped.jpg',
#   'ukbench00305_vflip.jpg'],
#  'ukbench00311.jpg': ['ukbench00311_rotation.jpg',
#   'ukbench00311_hflip.jpg',
#   'ukbench00311_resize.jpg',
#   'ukbench00311_cropped.jpg',
#   'ukbench00311_vflip.jpg'],
#  'ukbench00315.jpg': ['ukbench00315_rotation.jpg',
#   'ukbench00315_hflip.jpg',
#   'ukbench00315_resize.jpg',
#   'ukbench00315_cropped.jpg',
#   'ukbench00315_vflip.jpg'],
#  'ukbench00318.jpg': ['ukbench00318_rotation.jpg',
#   'ukbench00318_hflip.jpg',
#   'ukbench00318_resize.jpg',
#   'ukbench00318_cropped.jpg',
#   'ukbench00318_vflip.jpg'],
#  'ukbench00320.jpg': ['ukbench00320_rotation.jpg',
#   'ukbench00320_hflip.jpg',
#   'ukbench00320_resize.jpg',
#   'ukbench00320_cropped.jpg',
#   'ukbench00320_vflip.jpg'],
#  'ukbench00325.jpg': ['ukbench00325_rotation.jpg',
#   'ukbench00325_hflip.jpg',
#   'ukbench00325_resize.jpg',
#   'ukbench00325_cropped.jpg',
#   'ukbench00325_vflip.jpg'],
#  'ukbench00329.jpg': ['ukbench00329_rotation.jpg',
#   'ukbench00329_hflip.jpg',
#   'ukbench00329_resize.jpg',
#   'ukbench00329_cropped.jpg',
#   'ukbench00329_vflip.jpg'],
#  'ukbench00334.jpg': ['ukbench00334_rotation.jpg',
#   'ukbench00334_hflip.jpg',
#   'ukbench00334_resize.jpg',
#   'ukbench00334_cropped.jpg',
#   'ukbench00334_vflip.jpg'],
#  'ukbench00337.jpg': ['ukbench00337_rotation.jpg',
#   'ukbench00337_hflip.jpg',
#   'ukbench00337_resize.jpg',
#   'ukbench00337_cropped.jpg',
#   'ukbench00337_vflip.jpg'],
#  'ukbench00341.jpg': ['ukbench00341_rotation.jpg',
#   'ukbench00341_hflip.jpg',
#   'ukbench00341_resize.jpg',
#   'ukbench00341_cropped.jpg',
#   'ukbench00341_vflip.jpg'],
#  'ukbench00345.jpg': ['ukbench00345_rotation.jpg',
#   'ukbench00345_hflip.jpg',
#   'ukbench00345_resize.jpg',
#   'ukbench00345_cropped.jpg',
#   'ukbench00345_vflip.jpg'],
#  'ukbench00349.jpg': ['ukbench00349_rotation.jpg',
#   'ukbench00349_hflip.jpg',
#   'ukbench00349_resize.jpg',
#   'ukbench00349_cropped.jpg',
#   'ukbench00349_vflip.jpg'],
#  'ukbench00355.jpg': ['ukbench00355_rotation.jpg',
#   'ukbench00355_hflip.jpg',
#   'ukbench00355_resize.jpg',
#   'ukbench00355_cropped.jpg',
#   'ukbench00355_vflip.jpg'],
#  'ukbench00359.jpg': ['ukbench00359_rotation.jpg',
#   'ukbench00359_hflip.jpg',
#   'ukbench00359_resize.jpg',
#   'ukbench00359_cropped.jpg',
#   'ukbench00359_vflip.jpg'],
#  'ukbench00362.jpg': ['ukbench00362_rotation.jpg',
#   'ukbench00362_hflip.jpg',
#   'ukbench00362_resize.jpg',
#   'ukbench00362_cropped.jpg',
#   'ukbench00362_vflip.jpg'],
#  'ukbench00366.jpg': ['ukbench00366_rotation.jpg',
#   'ukbench00366_hflip.jpg',
#   'ukbench00366_resize.jpg',
#   'ukbench00366_cropped.jpg',
#   'ukbench00366_vflip.jpg'],
#  'ukbench00369.jpg': ['ukbench00369_rotation.jpg',
#   'ukbench00369_hflip.jpg',
#   'ukbench00369_resize.jpg',
#   'ukbench00369_cropped.jpg',
#   'ukbench00369_vflip.jpg'],
#  'ukbench00374.jpg': ['ukbench00374_rotation.jpg',
#   'ukbench00374_hflip.jpg',
#   'ukbench00374_resize.jpg',
#   'ukbench00374_cropped.jpg',
#   'ukbench00374_vflip.jpg'],
#  'ukbench00379.jpg': ['ukbench00379_rotation.jpg',
#   'ukbench00379_hflip.jpg',
#   'ukbench00379_resize.jpg',
#   'ukbench00379_cropped.jpg',
#   'ukbench00379_vflip.jpg'],
#  'ukbench00383.jpg': ['ukbench00383_rotation.jpg',
#   'ukbench00383_hflip.jpg',
#   'ukbench00383_resize.jpg',
#   'ukbench00383_cropped.jpg',
#   'ukbench00383_vflip.jpg'],
#  'ukbench00385.jpg': ['ukbench00385_rotation.jpg',
#   'ukbench00385_hflip.jpg',
#   'ukbench00385_resize.jpg',
#   'ukbench00385_cropped.jpg',
#   'ukbench00385_vflip.jpg'],
#  'ukbench00391.jpg': ['ukbench00391_rotation.jpg',
#   'ukbench00391_hflip.jpg',
#   'ukbench00391_resize.jpg',
#   'ukbench00391_cropped.jpg',
#   'ukbench00391_vflip.jpg'],
#  'ukbench00393.jpg': ['ukbench00393_rotation.jpg',
#   'ukbench00393_hflip.jpg',
#   'ukbench00393_resize.jpg',
#   'ukbench00393_cropped.jpg',
#   'ukbench00393_vflip.jpg'],
#  'ukbench00398.jpg': ['ukbench00398_rotation.jpg',
#   'ukbench00398_hflip.jpg',
#   'ukbench00398_resize.jpg',
#   'ukbench00398_cropped.jpg',
#   'ukbench00398_vflip.jpg'],
#  'ukbench00402.jpg': ['ukbench00402_rotation.jpg',
#   'ukbench00402_hflip.jpg',
#   'ukbench00402_resize.jpg',
#   'ukbench00402_cropped.jpg',
#   'ukbench00402_vflip.jpg'],
#  'ukbench00406.jpg': ['ukbench00406_rotation.jpg',
#   'ukbench00406_hflip.jpg',
#   'ukbench00406_resize.jpg',
#   'ukbench00406_cropped.jpg',
#   'ukbench00406_vflip.jpg'],
#  'ukbench00411.jpg': ['ukbench00411_rotation.jpg',
#   'ukbench00411_hflip.jpg',
#   'ukbench00411_resize.jpg',
#   'ukbench00411_cropped.jpg',
#   'ukbench00411_vflip.jpg'],
#  'ukbench00413.jpg': ['ukbench00413_rotation.jpg',
#   'ukbench00413_hflip.jpg',
#   'ukbench00413_resize.jpg',
#   'ukbench00413_cropped.jpg',
#   'ukbench00413_vflip.jpg'],
#  'ukbench00418.jpg': ['ukbench00418_rotation.jpg',
#   'ukbench00418_hflip.jpg',
#   'ukbench00418_resize.jpg',
#   'ukbench00418_cropped.jpg',
#   'ukbench00418_vflip.jpg'],
#  'ukbench00420.jpg': ['ukbench00420_rotation.jpg',
#   'ukbench00420_hflip.jpg',
#   'ukbench00420_resize.jpg',
#   'ukbench00420_cropped.jpg',
#   'ukbench00420_vflip.jpg'],
#  'ukbench00427.jpg': ['ukbench00427_rotation.jpg',
#   'ukbench00427_hflip.jpg',
#   'ukbench00427_resize.jpg',
#   'ukbench00427_cropped.jpg',
#   'ukbench00427_vflip.jpg'],
#  'ukbench00430.jpg': ['ukbench00430_rotation.jpg',
#   'ukbench00430_hflip.jpg',
#   'ukbench00430_resize.jpg',
#   'ukbench00430_cropped.jpg',
#   'ukbench00430_vflip.jpg'],
#  'ukbench00432.jpg': ['ukbench00432_rotation.jpg',
#   'ukbench00432_hflip.jpg',
#   'ukbench00432_resize.jpg',
#   'ukbench00432_cropped.jpg',
#   'ukbench00432_vflip.jpg'],
#  'ukbench00437.jpg': ['ukbench00437_rotation.jpg',
#   'ukbench00437_hflip.jpg',
#   'ukbench00437_resize.jpg',
#   'ukbench00437_cropped.jpg',
#   'ukbench00437_vflip.jpg'],
#  'ukbench00440.jpg': ['ukbench00440_rotation.jpg',
#   'ukbench00440_hflip.jpg',
#   'ukbench00440_resize.jpg',
#   'ukbench00440_cropped.jpg',
#   'ukbench00440_vflip.jpg'],
#  'ukbench00446.jpg': ['ukbench00446_rotation.jpg',
#   'ukbench00446_hflip.jpg',
#   'ukbench00446_resize.jpg',
#   'ukbench00446_cropped.jpg',
#   'ukbench00446_vflip.jpg'],
#  'ukbench00451.jpg': ['ukbench00451_rotation.jpg',
#   'ukbench00451_hflip.jpg',
#   'ukbench00451_resize.jpg',
#   'ukbench00451_cropped.jpg',
#   'ukbench00451_vflip.jpg'],
#  'ukbench00452.jpg': ['ukbench00452_rotation.jpg',
#   'ukbench00452_hflip.jpg',
#   'ukbench00452_resize.jpg',
#   'ukbench00452_cropped.jpg',
#   'ukbench00452_vflip.jpg'],
#  'ukbench00459.jpg': ['ukbench00459_rotation.jpg',
#   'ukbench00459_hflip.jpg',
#   'ukbench00459_resize.jpg',
#   'ukbench00459_cropped.jpg',
#   'ukbench00459_vflip.jpg'],
#  'ukbench00462.jpg': ['ukbench00462_rotation.jpg',
#   'ukbench00462_hflip.jpg',
#   'ukbench00462_resize.jpg',
#   'ukbench00462_cropped.jpg',
#   'ukbench00462_vflip.jpg'],
#  'ukbench00466.jpg': ['ukbench00466_rotation.jpg',
#   'ukbench00466_hflip.jpg',
#   'ukbench00466_resize.jpg',
#   'ukbench00466_cropped.jpg',
#   'ukbench00466_vflip.jpg'],
#  'ukbench00469.jpg': ['ukbench00469_rotation.jpg',
#   'ukbench00469_hflip.jpg',
#   'ukbench00469_resize.jpg',
#   'ukbench00469_cropped.jpg',
#   'ukbench00469_vflip.jpg'],
#  'ukbench00473.jpg': ['ukbench00473_rotation.jpg',
#   'ukbench00473_hflip.jpg',
#   'ukbench00473_resize.jpg',
#   'ukbench00473_cropped.jpg',
#   'ukbench00473_vflip.jpg'],
#  'ukbench00479.jpg': ['ukbench00479_rotation.jpg',
#   'ukbench00479_hflip.jpg',
#   'ukbench00479_resize.jpg',
#   'ukbench00479_cropped.jpg',
#   'ukbench00479_vflip.jpg'],
#  'ukbench00482.jpg': ['ukbench00482_rotation.jpg',
#   'ukbench00482_hflip.jpg',
#   'ukbench00482_resize.jpg',
#   'ukbench00482_cropped.jpg',
#   'ukbench00482_vflip.jpg'],
#  'ukbench00486.jpg': ['ukbench00486_rotation.jpg',
#   'ukbench00486_hflip.jpg',
#   'ukbench00486_resize.jpg',
#   'ukbench00486_cropped.jpg',
#   'ukbench00486_vflip.jpg'],
#  'ukbench00489.jpg': ['ukbench00489_rotation.jpg',
#   'ukbench00489_hflip.jpg',
#   'ukbench00489_resize.jpg',
#   'ukbench00489_cropped.jpg',
#   'ukbench00489_vflip.jpg'],
#  'ukbench00494.jpg': ['ukbench00494_rotation.jpg',
#   'ukbench00494_hflip.jpg',
#   'ukbench00494_resize.jpg',
#   'ukbench00494_cropped.jpg',
#   'ukbench00494_vflip.jpg'],
#  'ukbench00496.jpg': ['ukbench00496_rotation.jpg',
#   'ukbench00496_hflip.jpg',
#   'ukbench00496_resize.jpg',
#   'ukbench00496_cropped.jpg',
#   'ukbench00496_vflip.jpg'],
#  'ukbench00501.jpg': ['ukbench00501_rotation.jpg',
#   'ukbench00501_hflip.jpg',
#   'ukbench00501_resize.jpg',
#   'ukbench00501_cropped.jpg',
#   'ukbench00501_vflip.jpg'],
#  'ukbench00505.jpg': ['ukbench00505_rotation.jpg',
#   'ukbench00505_hflip.jpg',
#   'ukbench00505_resize.jpg',
#   'ukbench00505_cropped.jpg',
#   'ukbench00505_vflip.jpg'],
#  'ukbench00511.jpg': ['ukbench00511_rotation.jpg',
#   'ukbench00511_hflip.jpg',
#   'ukbench00511_resize.jpg',
#   'ukbench00511_cropped.jpg',
#   'ukbench00511_vflip.jpg'],
#  'ukbench00515.jpg': ['ukbench00515_rotation.jpg',
#   'ukbench00515_hflip.jpg',
#   'ukbench00515_resize.jpg',
#   'ukbench00515_cropped.jpg',
#   'ukbench00515_vflip.jpg'],
#  'ukbench00519.jpg': ['ukbench00519_rotation.jpg',
#   'ukbench00519_hflip.jpg',
#   'ukbench00519_resize.jpg',
#   'ukbench00519_cropped.jpg',
#   'ukbench00519_vflip.jpg'],
#  'ukbench00523.jpg': ['ukbench00523_rotation.jpg',
#   'ukbench00523_hflip.jpg',
#   'ukbench00523_resize.jpg',
#   'ukbench00523_cropped.jpg',
#   'ukbench00523_vflip.jpg'],
#  'ukbench00526.jpg': ['ukbench00526_rotation.jpg',
#   'ukbench00526_hflip.jpg',
#   'ukbench00526_resize.jpg',
#   'ukbench00526_cropped.jpg',
#   'ukbench00526_vflip.jpg'],
#  'ukbench00531.jpg': ['ukbench00531_rotation.jpg',
#   'ukbench00531_hflip.jpg',
#   'ukbench00531_resize.jpg',
#   'ukbench00531_cropped.jpg',
#   'ukbench00531_vflip.jpg'],
#  'ukbench00533.jpg': ['ukbench00533_rotation.jpg',
#   'ukbench00533_hflip.jpg',
#   'ukbench00533_resize.jpg',
#   'ukbench00533_cropped.jpg',
#   'ukbench00533_vflip.jpg'],
#  'ukbench00538.jpg': ['ukbench00538_rotation.jpg',
#   'ukbench00538_hflip.jpg',
#   'ukbench00538_resize.jpg',
#   'ukbench00538_cropped.jpg',
#   'ukbench00538_vflip.jpg'],
#  'ukbench00543.jpg': ['ukbench00543_rotation.jpg',
#   'ukbench00543_hflip.jpg',
#   'ukbench00543_resize.jpg',
#   'ukbench00543_cropped.jpg',
#   'ukbench00543_vflip.jpg'],
#  'ukbench00545.jpg': ['ukbench00545_rotation.jpg',
#   'ukbench00545_hflip.jpg',
#   'ukbench00545_resize.jpg',
#   'ukbench00545_cropped.jpg',
#   'ukbench00545_vflip.jpg'],
#  'ukbench00551.jpg': ['ukbench00551_rotation.jpg',
#   'ukbench00551_hflip.jpg',
#   'ukbench00551_resize.jpg',
#   'ukbench00551_cropped.jpg',
#   'ukbench00551_vflip.jpg'],
#  'ukbench00553.jpg': ['ukbench00553_rotation.jpg',
#   'ukbench00553_hflip.jpg',
#   'ukbench00553_resize.jpg',
#   'ukbench00553_cropped.jpg',
#   'ukbench00553_vflip.jpg'],
#  'ukbench00557.jpg': ['ukbench00557_rotation.jpg',
#   'ukbench00557_hflip.jpg',
#   'ukbench00557_resize.jpg',
#   'ukbench00557_cropped.jpg',
#   'ukbench00557_vflip.jpg'],
#  'ukbench00562.jpg': ['ukbench00562_rotation.jpg',
#   'ukbench00562_hflip.jpg',
#   'ukbench00562_resize.jpg',
#   'ukbench00562_cropped.jpg',
#   'ukbench00562_vflip.jpg'],
#  'ukbench00564.jpg': ['ukbench00564_rotation.jpg',
#   'ukbench00564_hflip.jpg',
#   'ukbench00564_resize.jpg',
#   'ukbench00564_cropped.jpg',
#   'ukbench00564_vflip.jpg'],
#  'ukbench00570.jpg': ['ukbench00570_rotation.jpg',
#   'ukbench00570_hflip.jpg',
#   'ukbench00570_resize.jpg',
#   'ukbench00570_cropped.jpg',
#   'ukbench00570_vflip.jpg'],
#  'ukbench00573.jpg': ['ukbench00573_rotation.jpg',
#   'ukbench00573_hflip.jpg',
#   'ukbench00573_resize.jpg',
#   'ukbench00573_cropped.jpg',
#   'ukbench00573_vflip.jpg'],
#  'ukbench00577.jpg': ['ukbench00577_rotation.jpg',
#   'ukbench00577_hflip.jpg',
#   'ukbench00577_resize.jpg',
#   'ukbench00577_cropped.jpg',
#   'ukbench00577_vflip.jpg'],
#  'ukbench00583.jpg': ['ukbench00583_rotation.jpg',
#   'ukbench00583_hflip.jpg',
#   'ukbench00583_resize.jpg',
#   'ukbench00583_cropped.jpg',
#   'ukbench00583_vflip.jpg'],
#  'ukbench00584.jpg': ['ukbench00584_rotation.jpg',
#   'ukbench00584_hflip.jpg',
#   'ukbench00584_resize.jpg',
#   'ukbench00584_cropped.jpg',
#   'ukbench00584_vflip.jpg'],
#  'ukbench00590.jpg': ['ukbench00590_rotation.jpg',
#   'ukbench00590_hflip.jpg',
#   'ukbench00590_resize.jpg',
#   'ukbench00590_cropped.jpg',
#   'ukbench00590_vflip.jpg'],
#  'ukbench00594.jpg': ['ukbench00594_rotation.jpg',
#   'ukbench00594_hflip.jpg',
#   'ukbench00594_resize.jpg',
#   'ukbench00594_cropped.jpg',
#   'ukbench00594_vflip.jpg'],
#  'ukbench00596.jpg': ['ukbench00596_rotation.jpg',
#   'ukbench00596_hflip.jpg',
#   'ukbench00596_resize.jpg',
#   'ukbench00596_cropped.jpg',
#   'ukbench00596_vflip.jpg'],
#  'ukbench00603.jpg': ['ukbench00603_rotation.jpg',
#   'ukbench00603_hflip.jpg',
#   'ukbench00603_resize.jpg',
#   'ukbench00603_cropped.jpg',
#   'ukbench00603_vflip.jpg'],
#  'ukbench00607.jpg': ['ukbench00607_rotation.jpg',
#   'ukbench00607_hflip.jpg',
#   'ukbench00607_resize.jpg',
#   'ukbench00607_cropped.jpg',
#   'ukbench00607_vflip.jpg'],
#  'ukbench00609.jpg': ['ukbench00609_rotation.jpg',
#   'ukbench00609_hflip.jpg',
#   'ukbench00609_resize.jpg',
#   'ukbench00609_cropped.jpg',
#   'ukbench00609_vflip.jpg'],
#  'ukbench00612.jpg': ['ukbench00612_rotation.jpg',
#   'ukbench00612_hflip.jpg',
#   'ukbench00612_resize.jpg',
#   'ukbench00612_cropped.jpg',
#   'ukbench00612_vflip.jpg'],
#  'ukbench00618.jpg': ['ukbench00618_rotation.jpg',
#   'ukbench00618_hflip.jpg',
#   'ukbench00618_resize.jpg',
#   'ukbench00618_cropped.jpg',
#   'ukbench00618_vflip.jpg'],
#  'ukbench00623.jpg': ['ukbench00623_rotation.jpg',
#   'ukbench00623_hflip.jpg',
#   'ukbench00623_resize.jpg',
#   'ukbench00623_cropped.jpg',
#   'ukbench00623_vflip.jpg'],
#  'ukbench00627.jpg': ['ukbench00627_rotation.jpg',
#   'ukbench00627_hflip.jpg',
#   'ukbench00627_resize.jpg',
#   'ukbench00627_cropped.jpg',
#   'ukbench00627_vflip.jpg'],
#  'ukbench00631.jpg': ['ukbench00631_rotation.jpg',
#   'ukbench00631_hflip.jpg',
#   'ukbench00631_resize.jpg',
#   'ukbench00631_cropped.jpg',
#   'ukbench00631_vflip.jpg'],
#  'ukbench00633.jpg': ['ukbench00633_rotation.jpg',
#   'ukbench00633_hflip.jpg',
#   'ukbench00633_resize.jpg',
#   'ukbench00633_cropped.jpg',
#   'ukbench00633_vflip.jpg'],
#  'ukbench00636.jpg': ['ukbench00636_rotation.jpg',
#   'ukbench00636_hflip.jpg',
#   'ukbench00636_resize.jpg',
#   'ukbench00636_cropped.jpg',
#   'ukbench00636_vflip.jpg'],
#  'ukbench00643.jpg': ['ukbench00643_rotation.jpg',
#   'ukbench00643_hflip.jpg',
#   'ukbench00643_resize.jpg',
#   'ukbench00643_cropped.jpg',
#   'ukbench00643_vflip.jpg'],
#  'ukbench00645.jpg': ['ukbench00645_rotation.jpg',
#   'ukbench00645_hflip.jpg',
#   'ukbench00645_resize.jpg',
#   'ukbench00645_cropped.jpg',
#   'ukbench00645_vflip.jpg'],
#  'ukbench00648.jpg': ['ukbench00648_rotation.jpg',
#   'ukbench00648_hflip.jpg',
#   'ukbench00648_resize.jpg',
#   'ukbench00648_cropped.jpg',
#   'ukbench00648_vflip.jpg'],
#  'ukbench00653.jpg': ['ukbench00653_rotation.jpg',
#   'ukbench00653_hflip.jpg',
#   'ukbench00653_resize.jpg',
#   'ukbench00653_cropped.jpg',
#   'ukbench00653_vflip.jpg'],
#  'ukbench00656.jpg': ['ukbench00656_rotation.jpg',
#   'ukbench00656_hflip.jpg',
#   'ukbench00656_resize.jpg',
#   'ukbench00656_cropped.jpg',
#   'ukbench00656_vflip.jpg'],
#  'ukbench00661.jpg': ['ukbench00661_rotation.jpg',
#   'ukbench00661_hflip.jpg',
#   'ukbench00661_resize.jpg',
#   'ukbench00661_cropped.jpg',
#   'ukbench00661_vflip.jpg'],
#  'ukbench00666.jpg': ['ukbench00666_rotation.jpg',
#   'ukbench00666_hflip.jpg',
#   'ukbench00666_resize.jpg',
#   'ukbench00666_cropped.jpg',
#   'ukbench00666_vflip.jpg'],
#  'ukbench00671.jpg': ['ukbench00671_rotation.jpg',
#   'ukbench00671_hflip.jpg',
#   'ukbench00671_resize.jpg',
#   'ukbench00671_cropped.jpg',
#   'ukbench00671_vflip.jpg'],
#  'ukbench00675.jpg': ['ukbench00675_rotation.jpg',
#   'ukbench00675_hflip.jpg',
#   'ukbench00675_resize.jpg',
#   'ukbench00675_cropped.jpg',
#   'ukbench00675_vflip.jpg'],
#  'ukbench00676.jpg': ['ukbench00676_rotation.jpg',
#   'ukbench00676_hflip.jpg',
#   'ukbench00676_resize.jpg',
#   'ukbench00676_cropped.jpg',
#   'ukbench00676_vflip.jpg'],
#  'ukbench00681.jpg': ['ukbench00681_rotation.jpg',
#   'ukbench00681_hflip.jpg',
#   'ukbench00681_resize.jpg',
#   'ukbench00681_cropped.jpg',
#   'ukbench00681_vflip.jpg'],
#  'ukbench00686.jpg': ['ukbench00686_rotation.jpg',
#   'ukbench00686_hflip.jpg',
#   'ukbench00686_resize.jpg',
#   'ukbench00686_cropped.jpg',
#   'ukbench00686_vflip.jpg'],
#  'ukbench00688.jpg': ['ukbench00688_rotation.jpg',
#   'ukbench00688_hflip.jpg',
#   'ukbench00688_resize.jpg',
#   'ukbench00688_cropped.jpg',
#   'ukbench00688_vflip.jpg'],
#  'ukbench00695.jpg': ['ukbench00695_rotation.jpg',
#   'ukbench00695_hflip.jpg',
#   'ukbench00695_resize.jpg',
#   'ukbench00695_cropped.jpg',
#   'ukbench00695_vflip.jpg'],
#  'ukbench00699.jpg': ['ukbench00699_rotation.jpg',
#   'ukbench00699_hflip.jpg',
#   'ukbench00699_resize.jpg',
#   'ukbench00699_cropped.jpg',
#   'ukbench00699_vflip.jpg'],
#  'ukbench00701.jpg': ['ukbench00701_rotation.jpg',
#   'ukbench00701_hflip.jpg',
#   'ukbench00701_resize.jpg',
#   'ukbench00701_cropped.jpg',
#   'ukbench00701_vflip.jpg'],
#  'ukbench00706.jpg': ['ukbench00706_rotation.jpg',
#   'ukbench00706_hflip.jpg',
#   'ukbench00706_resize.jpg',
#   'ukbench00706_cropped.jpg',
#   'ukbench00706_vflip.jpg'],
#  'ukbench00711.jpg': ['ukbench00711_rotation.jpg',
#   'ukbench00711_hflip.jpg',
#   'ukbench00711_resize.jpg',
#   'ukbench00711_cropped.jpg',
#   'ukbench00711_vflip.jpg'],
#  'ukbench00715.jpg': ['ukbench00715_rotation.jpg',
#   'ukbench00715_hflip.jpg',
#   'ukbench00715_resize.jpg',
#   'ukbench00715_cropped.jpg',
#   'ukbench00715_vflip.jpg'],
#  'ukbench00719.jpg': ['ukbench00719_rotation.jpg',
#   'ukbench00719_hflip.jpg',
#   'ukbench00719_resize.jpg',
#   'ukbench00719_cropped.jpg',
#   'ukbench00719_vflip.jpg'],
#  'ukbench00723.jpg': ['ukbench00723_rotation.jpg',
#   'ukbench00723_hflip.jpg',
#   'ukbench00723_resize.jpg',
#   'ukbench00723_cropped.jpg',
#   'ukbench00723_vflip.jpg'],
#  'ukbench00725.jpg': ['ukbench00725_rotation.jpg',
#   'ukbench00725_hflip.jpg',
#   'ukbench00725_resize.jpg',
#   'ukbench00725_cropped.jpg',
#   'ukbench00725_vflip.jpg'],
#  'ukbench00731.jpg': ['ukbench00731_rotation.jpg',
#   'ukbench00731_hflip.jpg',
#   'ukbench00731_resize.jpg',
#   'ukbench00731_cropped.jpg',
#   'ukbench00731_vflip.jpg'],
#  'ukbench00732.jpg': ['ukbench00732_rotation.jpg',
#   'ukbench00732_hflip.jpg',
#   'ukbench00732_resize.jpg',
#   'ukbench00732_cropped.jpg',
#   'ukbench00732_vflip.jpg'],
#  'ukbench00737.jpg': ['ukbench00737_rotation.jpg',
#   'ukbench00737_hflip.jpg',
#   'ukbench00737_resize.jpg',
#   'ukbench00737_cropped.jpg',
#   'ukbench00737_vflip.jpg'],
#  'ukbench00742.jpg': ['ukbench00742_rotation.jpg',
#   'ukbench00742_hflip.jpg',
#   'ukbench00742_resize.jpg',
#   'ukbench00742_cropped.jpg',
#   'ukbench00742_vflip.jpg'],
#  'ukbench00747.jpg': ['ukbench00747_rotation.jpg',
#   'ukbench00747_hflip.jpg',
#   'ukbench00747_resize.jpg',
#   'ukbench00747_cropped.jpg',
#   'ukbench00747_vflip.jpg'],
#  'ukbench00751.jpg': ['ukbench00751_rotation.jpg',
#   'ukbench00751_hflip.jpg',
#   'ukbench00751_resize.jpg',
#   'ukbench00751_cropped.jpg',
#   'ukbench00751_vflip.jpg'],
#  'ukbench00755.jpg': ['ukbench00755_rotation.jpg',
#   'ukbench00755_hflip.jpg',
#   'ukbench00755_resize.jpg',
#   'ukbench00755_cropped.jpg',
#   'ukbench00755_vflip.jpg'],
#  'ukbench00757.jpg': ['ukbench00757_rotation.jpg',
#   'ukbench00757_hflip.jpg',
#   'ukbench00757_resize.jpg',
#   'ukbench00757_cropped.jpg',
#   'ukbench00757_vflip.jpg'],
#  'ukbench00763.jpg': ['ukbench00763_rotation.jpg',
#   'ukbench00763_hflip.jpg',
#   'ukbench00763_resize.jpg',
#   'ukbench00763_cropped.jpg',
#   'ukbench00763_vflip.jpg'],
#  'ukbench00766.jpg': ['ukbench00766_rotation.jpg',
#   'ukbench00766_hflip.jpg',
#   'ukbench00766_resize.jpg',
#   'ukbench00766_cropped.jpg',
#   'ukbench00766_vflip.jpg'],
#  'ukbench00769.jpg': ['ukbench00769_rotation.jpg',
#   'ukbench00769_hflip.jpg',
#   'ukbench00769_resize.jpg',
#   'ukbench00769_cropped.jpg',
#   'ukbench00769_vflip.jpg'],
#  'ukbench00774.jpg': ['ukbench00774_rotation.jpg',
#   'ukbench00774_hflip.jpg',
#   'ukbench00774_resize.jpg',
#   'ukbench00774_cropped.jpg',
#   'ukbench00774_vflip.jpg'],
#  'ukbench00776.jpg': ['ukbench00776_rotation.jpg',
#   'ukbench00776_hflip.jpg',
#   'ukbench00776_resize.jpg',
#   'ukbench00776_cropped.jpg',
#   'ukbench00776_vflip.jpg'],
#  'ukbench00782.jpg': ['ukbench00782_rotation.jpg',
#   'ukbench00782_hflip.jpg',
#   'ukbench00782_resize.jpg',
#   'ukbench00782_cropped.jpg',
#   'ukbench00782_vflip.jpg'],
#  'ukbench00786.jpg': ['ukbench00786_rotation.jpg',
#   'ukbench00786_hflip.jpg',
#   'ukbench00786_resize.jpg',
#   'ukbench00786_cropped.jpg',
#   'ukbench00786_vflip.jpg'],
#  'ukbench00789.jpg': ['ukbench00789_rotation.jpg',
#   'ukbench00789_hflip.jpg',
#   'ukbench00789_resize.jpg',
#   'ukbench00789_cropped.jpg',
#   'ukbench00789_vflip.jpg'],
#  'ukbench00794.jpg': ['ukbench00794_rotation.jpg',
#   'ukbench00794_hflip.jpg',
#   'ukbench00794_resize.jpg',
#   'ukbench00794_cropped.jpg',
#   'ukbench00794_vflip.jpg'],
#  'ukbench00798.jpg': ['ukbench00798_rotation.jpg',
#   'ukbench00798_hflip.jpg',
#   'ukbench00798_resize.jpg',
#   'ukbench00798_cropped.jpg',
#   'ukbench00798_vflip.jpg'],
#  'ukbench00803.jpg': ['ukbench00803_rotation.jpg',
#   'ukbench00803_hflip.jpg',
#   'ukbench00803_resize.jpg',
#   'ukbench00803_cropped.jpg',
#   'ukbench00803_vflip.jpg'],
#  'ukbench00806.jpg': ['ukbench00806_rotation.jpg',
#   'ukbench00806_hflip.jpg',
#   'ukbench00806_resize.jpg',
#   'ukbench00806_cropped.jpg',
#   'ukbench00806_vflip.jpg'],
#  'ukbench00810.jpg': ['ukbench00810_rotation.jpg',
#   'ukbench00810_hflip.jpg',
#   'ukbench00810_resize.jpg',
#   'ukbench00810_cropped.jpg',
#   'ukbench00810_vflip.jpg'],
#  'ukbench00815.jpg': ['ukbench00815_rotation.jpg',
#   'ukbench00815_hflip.jpg',
#   'ukbench00815_resize.jpg',
#   'ukbench00815_cropped.jpg',
#   'ukbench00815_vflip.jpg'],
#  'ukbench00818.jpg': ['ukbench00818_rotation.jpg',
#   'ukbench00818_hflip.jpg',
#   'ukbench00818_resize.jpg',
#   'ukbench00818_cropped.jpg',
#   'ukbench00818_vflip.jpg'],
#  'ukbench00821.jpg': ['ukbench00821_rotation.jpg',
#   'ukbench00821_hflip.jpg',
#   'ukbench00821_resize.jpg',
#   'ukbench00821_cropped.jpg',
#   'ukbench00821_vflip.jpg'],
#  'ukbench00827.jpg': ['ukbench00827_rotation.jpg',
#   'ukbench00827_hflip.jpg',
#   'ukbench00827_resize.jpg',
#   'ukbench00827_cropped.jpg',
#   'ukbench00827_vflip.jpg'],
#  'ukbench00831.jpg': ['ukbench00831_rotation.jpg',
#   'ukbench00831_hflip.jpg',
#   'ukbench00831_resize.jpg',
#   'ukbench00831_cropped.jpg',
#   'ukbench00831_vflip.jpg'],
#  'ukbench00833.jpg': ['ukbench00833_rotation.jpg',
#   'ukbench00833_hflip.jpg',
#   'ukbench00833_resize.jpg',
#   'ukbench00833_cropped.jpg',
#   'ukbench00833_vflip.jpg'],
#  'ukbench00839.jpg': ['ukbench00839_rotation.jpg',
#   'ukbench00839_hflip.jpg',
#   'ukbench00839_resize.jpg',
#   'ukbench00839_cropped.jpg',
#   'ukbench00839_vflip.jpg'],
#  'ukbench00841.jpg': ['ukbench00841_rotation.jpg',
#   'ukbench00841_hflip.jpg',
#   'ukbench00841_resize.jpg',
#   'ukbench00841_cropped.jpg',
#   'ukbench00841_vflip.jpg'],
#  'ukbench00845.jpg': ['ukbench00845_rotation.jpg',
#   'ukbench00845_hflip.jpg',
#   'ukbench00845_resize.jpg',
#   'ukbench00845_cropped.jpg',
#   'ukbench00845_vflip.jpg'],
#  'ukbench00850.jpg': ['ukbench00850_rotation.jpg',
#   'ukbench00850_hflip.jpg',
#   'ukbench00850_resize.jpg',
#   'ukbench00850_cropped.jpg',
#   'ukbench00850_vflip.jpg'],
#  'ukbench00854.jpg': ['ukbench00854_rotation.jpg',
#   'ukbench00854_hflip.jpg',
#   'ukbench00854_resize.jpg',
#   'ukbench00854_cropped.jpg',
#   'ukbench00854_vflip.jpg'],
#  'ukbench00857.jpg': ['ukbench00857_rotation.jpg',
#   'ukbench00857_hflip.jpg',
#   'ukbench00857_resize.jpg',
#   'ukbench00857_cropped.jpg',
#   'ukbench00857_vflip.jpg'],
#  'ukbench00862.jpg': ['ukbench00862_rotation.jpg',
#   'ukbench00862_hflip.jpg',
#   'ukbench00862_resize.jpg',
#   'ukbench00862_cropped.jpg',
#   'ukbench00862_vflip.jpg'],
#  'ukbench00867.jpg': ['ukbench00867_rotation.jpg',
#   'ukbench00867_hflip.jpg',
#   'ukbench00867_resize.jpg',
#   'ukbench00867_cropped.jpg',
#   'ukbench00867_vflip.jpg'],
#  'ukbench00870.jpg': ['ukbench00870_rotation.jpg',
#   'ukbench00870_hflip.jpg',
#   'ukbench00870_resize.jpg',
#   'ukbench00870_cropped.jpg',
#   'ukbench00870_vflip.jpg'],
#  'ukbench00872.jpg': ['ukbench00872_rotation.jpg',
#   'ukbench00872_hflip.jpg',
#   'ukbench00872_resize.jpg',
#   'ukbench00872_cropped.jpg',
#   'ukbench00872_vflip.jpg'],
#  'ukbench00877.jpg': ['ukbench00877_rotation.jpg',
#   'ukbench00877_hflip.jpg',
#   'ukbench00877_resize.jpg',
#   'ukbench00877_cropped.jpg',
#   'ukbench00877_vflip.jpg'],
#  'ukbench00883.jpg': ['ukbench00883_rotation.jpg',
#   'ukbench00883_hflip.jpg',
#   'ukbench00883_resize.jpg',
#   'ukbench00883_cropped.jpg',
#   'ukbench00883_vflip.jpg'],
#  'ukbench00887.jpg': ['ukbench00887_rotation.jpg',
#   'ukbench00887_hflip.jpg',
#   'ukbench00887_resize.jpg',
#   'ukbench00887_cropped.jpg',
#   'ukbench00887_vflip.jpg'],
#  'ukbench00888.jpg': ['ukbench00888_rotation.jpg',
#   'ukbench00888_hflip.jpg',
#   'ukbench00888_resize.jpg',
#   'ukbench00888_cropped.jpg',
#   'ukbench00888_vflip.jpg'],
#  'ukbench00894.jpg': ['ukbench00894_rotation.jpg',
#   'ukbench00894_hflip.jpg',
#   'ukbench00894_resize.jpg',
#   'ukbench00894_cropped.jpg',
#   'ukbench00894_vflip.jpg'],
#  'ukbench00898.jpg': ['ukbench00898_rotation.jpg',
#   'ukbench00898_hflip.jpg',
#   'ukbench00898_resize.jpg',
#   'ukbench00898_cropped.jpg',
#   'ukbench00898_vflip.jpg'],
#  'ukbench00902.jpg': ['ukbench00902_rotation.jpg',
#   'ukbench00902_hflip.jpg',
#   'ukbench00902_resize.jpg',
#   'ukbench00902_cropped.jpg',
#   'ukbench00902_vflip.jpg'],
#  'ukbench00905.jpg': ['ukbench00905_rotation.jpg',
#   'ukbench00905_hflip.jpg',
#   'ukbench00905_resize.jpg',
#   'ukbench00905_cropped.jpg',
#   'ukbench00905_vflip.jpg'],
#  'ukbench00911.jpg': ['ukbench00911_rotation.jpg',
#   'ukbench00911_hflip.jpg',
#   'ukbench00911_resize.jpg',
#   'ukbench00911_cropped.jpg',
#   'ukbench00911_vflip.jpg'],
#  'ukbench00913.jpg': ['ukbench00913_rotation.jpg',
#   'ukbench00913_hflip.jpg',
#   'ukbench00913_resize.jpg',
#   'ukbench00913_cropped.jpg',
#   'ukbench00913_vflip.jpg'],
#  'ukbench00919.jpg': ['ukbench00919_rotation.jpg',
#   'ukbench00919_hflip.jpg',
#   'ukbench00919_resize.jpg',
#   'ukbench00919_cropped.jpg',
#   'ukbench00919_vflip.jpg'],
#  'ukbench00921.jpg': ['ukbench00921_rotation.jpg',
#   'ukbench00921_hflip.jpg',
#   'ukbench00921_resize.jpg',
#   'ukbench00921_cropped.jpg',
#   'ukbench00921_vflip.jpg'],
#  'ukbench00925.jpg': ['ukbench00925_rotation.jpg',
#   'ukbench00925_hflip.jpg',
#   'ukbench00925_resize.jpg',
#   'ukbench00925_cropped.jpg',
#   'ukbench00925_vflip.jpg'],
#  'ukbench00928.jpg': ['ukbench00928_rotation.jpg',
#   'ukbench00928_hflip.jpg',
#   'ukbench00928_resize.jpg',
#   'ukbench00928_cropped.jpg',
#   'ukbench00928_vflip.jpg'],
#  'ukbench00932.jpg': ['ukbench00932_rotation.jpg',
#   'ukbench00932_hflip.jpg',
#   'ukbench00932_resize.jpg',
#   'ukbench00932_cropped.jpg',
#   'ukbench00932_vflip.jpg'],
#  'ukbench00939.jpg': ['ukbench00939_rotation.jpg',
#   'ukbench00939_hflip.jpg',
#   'ukbench00939_resize.jpg',
#   'ukbench00939_cropped.jpg',
#   'ukbench00939_vflip.jpg'],
#  'ukbench00942.jpg': ['ukbench00942_rotation.jpg',
#   'ukbench00942_hflip.jpg',
#   'ukbench00942_resize.jpg',
#   'ukbench00942_cropped.jpg',
#   'ukbench00942_vflip.jpg'],
#  'ukbench00945.jpg': ['ukbench00945_rotation.jpg',
#   'ukbench00945_hflip.jpg',
#   'ukbench00945_resize.jpg',
#   'ukbench00945_cropped.jpg',
#   'ukbench00945_vflip.jpg'],
#  'ukbench00951.jpg': ['ukbench00951_rotation.jpg',
#   'ukbench00951_hflip.jpg',
#   'ukbench00951_resize.jpg',
#   'ukbench00951_cropped.jpg',
#   'ukbench00951_vflip.jpg'],
#  'ukbench00953.jpg': ['ukbench00953_rotation.jpg',
#   'ukbench00953_hflip.jpg',
#   'ukbench00953_resize.jpg',
#   'ukbench00953_cropped.jpg',
#   'ukbench00953_vflip.jpg'],
#  'ukbench00959.jpg': ['ukbench00959_rotation.jpg',
#   'ukbench00959_hflip.jpg',
#   'ukbench00959_resize.jpg',
#   'ukbench00959_cropped.jpg',
#   'ukbench00959_vflip.jpg'],
#  'ukbench00960.jpg': ['ukbench00960_rotation.jpg',
#   'ukbench00960_hflip.jpg',
#   'ukbench00960_resize.jpg',
#   'ukbench00960_cropped.jpg',
#   'ukbench00960_vflip.jpg'],
#  'ukbench00965.jpg': ['ukbench00965_rotation.jpg',
#   'ukbench00965_hflip.jpg',
#   'ukbench00965_resize.jpg',
#   'ukbench00965_cropped.jpg',
#   'ukbench00965_vflip.jpg'],
#  'ukbench00969.jpg': ['ukbench00969_rotation.jpg',
#   'ukbench00969_hflip.jpg',
#   'ukbench00969_resize.jpg',
#   'ukbench00969_cropped.jpg',
#   'ukbench00969_vflip.jpg'],
#  'ukbench00973.jpg': ['ukbench00973_rotation.jpg',
#   'ukbench00973_hflip.jpg',
#   'ukbench00973_resize.jpg',
#   'ukbench00973_cropped.jpg',
#   'ukbench00973_vflip.jpg'],
#  'ukbench00978.jpg': ['ukbench00978_rotation.jpg',
#   'ukbench00978_hflip.jpg',
#   'ukbench00978_resize.jpg',
#   'ukbench00978_cropped.jpg',
#   'ukbench00978_vflip.jpg'],
#  'ukbench00980.jpg': ['ukbench00980_rotation.jpg',
#   'ukbench00980_hflip.jpg',
#   'ukbench00980_resize.jpg',
#   'ukbench00980_cropped.jpg',
#   'ukbench00980_vflip.jpg'],
#  'ukbench00985.jpg': ['ukbench00985_rotation.jpg',
#   'ukbench00985_hflip.jpg',
#   'ukbench00985_resize.jpg',
#   'ukbench00985_cropped.jpg',
#   'ukbench00985_vflip.jpg'],
#  'ukbench00989.jpg': ['ukbench00989_rotation.jpg',
#   'ukbench00989_hflip.jpg',
#   'ukbench00989_resize.jpg',
#   'ukbench00989_cropped.jpg',
#   'ukbench00989_vflip.jpg'],
#  'ukbench00993.jpg': ['ukbench00993_rotation.jpg',
#   'ukbench00993_hflip.jpg',
#   'ukbench00993_resize.jpg',
#   'ukbench00993_cropped.jpg',
#   'ukbench00993_vflip.jpg'],
#  'ukbench00998.jpg': ['ukbench00998_rotation.jpg',
#   'ukbench00998_hflip.jpg',
#   'ukbench00998_resize.jpg',
#   'ukbench00998_cropped.jpg',
#   'ukbench00998_vflip.jpg'],
#  'ukbench01003.jpg': ['ukbench01003_rotation.jpg',
#   'ukbench01003_hflip.jpg',
#   'ukbench01003_resize.jpg',
#   'ukbench01003_cropped.jpg',
#   'ukbench01003_vflip.jpg'],
#  'ukbench01007.jpg': ['ukbench01007_rotation.jpg',
#   'ukbench01007_hflip.jpg',
#   'ukbench01007_resize.jpg',
#   'ukbench01007_cropped.jpg',
#   'ukbench01007_vflip.jpg'],
#  'ukbench01008.jpg': ['ukbench01008_rotation.jpg',
#   'ukbench01008_hflip.jpg',
#   'ukbench01008_resize.jpg',
#   'ukbench01008_cropped.jpg',
#   'ukbench01008_vflip.jpg'],
#  'ukbench01014.jpg': ['ukbench01014_rotation.jpg',
#   'ukbench01014_hflip.jpg',
#   'ukbench01014_resize.jpg',
#   'ukbench01014_cropped.jpg',
#   'ukbench01014_vflip.jpg'],
#  'ukbench01016.jpg': ['ukbench01016_rotation.jpg',
#   'ukbench01016_hflip.jpg',
#   'ukbench01016_resize.jpg',
#   'ukbench01016_cropped.jpg',
#   'ukbench01016_vflip.jpg'],
#  'ukbench01020.jpg': ['ukbench01020_rotation.jpg',
#   'ukbench01020_hflip.jpg',
#   'ukbench01020_resize.jpg',
#   'ukbench01020_cropped.jpg',
#   'ukbench01020_vflip.jpg'],
#  'ukbench01025.jpg': ['ukbench01025_rotation.jpg',
#   'ukbench01025_hflip.jpg',
#   'ukbench01025_resize.jpg',
#   'ukbench01025_cropped.jpg',
#   'ukbench01025_vflip.jpg'],
#  'ukbench01031.jpg': ['ukbench01031_rotation.jpg',
#   'ukbench01031_hflip.jpg',
#   'ukbench01031_resize.jpg',
#   'ukbench01031_cropped.jpg',
#   'ukbench01031_vflip.jpg'],
#  'ukbench01032.jpg': ['ukbench01032_rotation.jpg',
#   'ukbench01032_hflip.jpg',
#   'ukbench01032_resize.jpg',
#   'ukbench01032_cropped.jpg',
#   'ukbench01032_vflip.jpg'],
#  'ukbench01039.jpg': ['ukbench01039_rotation.jpg',
#   'ukbench01039_hflip.jpg',
#   'ukbench01039_resize.jpg',
#   'ukbench01039_cropped.jpg',
#   'ukbench01039_vflip.jpg'],
#  'ukbench01041.jpg': ['ukbench01041_rotation.jpg',
#   'ukbench01041_hflip.jpg',
#   'ukbench01041_resize.jpg',
#   'ukbench01041_cropped.jpg',
#   'ukbench01041_vflip.jpg'],
#  'ukbench01044.jpg': ['ukbench01044_rotation.jpg',
#   'ukbench01044_hflip.jpg',
#   'ukbench01044_resize.jpg',
#   'ukbench01044_cropped.jpg',
#   'ukbench01044_vflip.jpg'],
#  'ukbench01051.jpg': ['ukbench01051_rotation.jpg',
#   'ukbench01051_hflip.jpg',
#   'ukbench01051_resize.jpg',
#   'ukbench01051_cropped.jpg',
#   'ukbench01051_vflip.jpg'],
#  'ukbench01052.jpg': ['ukbench01052_rotation.jpg',
#   'ukbench01052_hflip.jpg',
#   'ukbench01052_resize.jpg',
#   'ukbench01052_cropped.jpg',
#   'ukbench01052_vflip.jpg'],
#  'ukbench01058.jpg': ['ukbench01058_rotation.jpg',
#   'ukbench01058_hflip.jpg',
#   'ukbench01058_resize.jpg',
#   'ukbench01058_cropped.jpg',
#   'ukbench01058_vflip.jpg'],
#  'ukbench01061.jpg': ['ukbench01061_rotation.jpg',
#   'ukbench01061_hflip.jpg',
#   'ukbench01061_resize.jpg',
#   'ukbench01061_cropped.jpg',
#   'ukbench01061_vflip.jpg'],
#  'ukbench01065.jpg': ['ukbench01065_rotation.jpg',
#   'ukbench01065_hflip.jpg',
#   'ukbench01065_resize.jpg',
#   'ukbench01065_cropped.jpg',
#   'ukbench01065_vflip.jpg'],
#  'ukbench01070.jpg': ['ukbench01070_rotation.jpg',
#   'ukbench01070_hflip.jpg',
#   'ukbench01070_resize.jpg',
#   'ukbench01070_cropped.jpg',
#   'ukbench01070_vflip.jpg'],
#  'ukbench01072.jpg': ['ukbench01072_rotation.jpg',
#   'ukbench01072_hflip.jpg',
#   'ukbench01072_resize.jpg',
#   'ukbench01072_cropped.jpg',
#   'ukbench01072_vflip.jpg'],
#  'ukbench01079.jpg': ['ukbench01079_rotation.jpg',
#   'ukbench01079_hflip.jpg',
#   'ukbench01079_resize.jpg',
#   'ukbench01079_cropped.jpg',
#   'ukbench01079_vflip.jpg'],
#  'ukbench01082.jpg': ['ukbench01082_rotation.jpg',
#   'ukbench01082_hflip.jpg',
#   'ukbench01082_resize.jpg',
#   'ukbench01082_cropped.jpg',
#   'ukbench01082_vflip.jpg'],
#  'ukbench01086.jpg': ['ukbench01086_rotation.jpg',
#   'ukbench01086_hflip.jpg',
#   'ukbench01086_resize.jpg',
#   'ukbench01086_cropped.jpg',
#   'ukbench01086_vflip.jpg'],
#  'ukbench01090.jpg': ['ukbench01090_rotation.jpg',
#   'ukbench01090_hflip.jpg',
#   'ukbench01090_resize.jpg',
#   'ukbench01090_cropped.jpg',
#   'ukbench01090_vflip.jpg'],
#  'ukbench01095.jpg': ['ukbench01095_rotation.jpg',
#   'ukbench01095_hflip.jpg',
#   'ukbench01095_resize.jpg',
#   'ukbench01095_cropped.jpg',
#   'ukbench01095_vflip.jpg'],
#  'ukbench01099.jpg': ['ukbench01099_rotation.jpg',
#   'ukbench01099_hflip.jpg',
#   'ukbench01099_resize.jpg',
#   'ukbench01099_cropped.jpg',
#   'ukbench01099_vflip.jpg'],
#  'ukbench01102.jpg': ['ukbench01102_rotation.jpg',
#   'ukbench01102_hflip.jpg',
#   'ukbench01102_resize.jpg',
#   'ukbench01102_cropped.jpg',
#   'ukbench01102_vflip.jpg'],
#  'ukbench01107.jpg': ['ukbench01107_rotation.jpg',
#   'ukbench01107_hflip.jpg',
#   'ukbench01107_resize.jpg',
#   'ukbench01107_cropped.jpg',
#   'ukbench01107_vflip.jpg'],
#  'ukbench01111.jpg': ['ukbench01111_rotation.jpg',
#   'ukbench01111_hflip.jpg',
#   'ukbench01111_resize.jpg',
#   'ukbench01111_cropped.jpg',
#   'ukbench01111_vflip.jpg'],
#  'ukbench01112.jpg': ['ukbench01112_rotation.jpg',
#   'ukbench01112_hflip.jpg',
#   'ukbench01112_resize.jpg',
#   'ukbench01112_cropped.jpg',
#   'ukbench01112_vflip.jpg'],
#  'ukbench01118.jpg': ['ukbench01118_rotation.jpg',
#   'ukbench01118_hflip.jpg',
#   'ukbench01118_resize.jpg',
#   'ukbench01118_cropped.jpg',
#   'ukbench01118_vflip.jpg'],
#  'ukbench01120.jpg': ['ukbench01120_rotation.jpg',
#   'ukbench01120_hflip.jpg',
#   'ukbench01120_resize.jpg',
#   'ukbench01120_cropped.jpg',
#   'ukbench01120_vflip.jpg'],
#  'ukbench01127.jpg': ['ukbench01127_rotation.jpg',
#   'ukbench01127_hflip.jpg',
#   'ukbench01127_resize.jpg',
#   'ukbench01127_cropped.jpg',
#   'ukbench01127_vflip.jpg'],
#  'ukbench01129.jpg': ['ukbench01129_rotation.jpg',
#   'ukbench01129_hflip.jpg',
#   'ukbench01129_resize.jpg',
#   'ukbench01129_cropped.jpg',
#   'ukbench01129_vflip.jpg'],
#  'ukbench01135.jpg': ['ukbench01135_rotation.jpg',
#   'ukbench01135_hflip.jpg',
#   'ukbench01135_resize.jpg',
#   'ukbench01135_cropped.jpg',
#   'ukbench01135_vflip.jpg'],
#  'ukbench01138.jpg': ['ukbench01138_rotation.jpg',
#   'ukbench01138_hflip.jpg',
#   'ukbench01138_resize.jpg',
#   'ukbench01138_cropped.jpg',
#   'ukbench01138_vflip.jpg'],
#  'ukbench01143.jpg': ['ukbench01143_rotation.jpg',
#   'ukbench01143_hflip.jpg',
#   'ukbench01143_resize.jpg',
#   'ukbench01143_cropped.jpg',
#   'ukbench01143_vflip.jpg'],
#  'ukbench01145.jpg': ['ukbench01145_rotation.jpg',
#   'ukbench01145_hflip.jpg',
#   'ukbench01145_resize.jpg',
#   'ukbench01145_cropped.jpg',
#   'ukbench01145_vflip.jpg'],
#  'ukbench01148.jpg': ['ukbench01148_rotation.jpg',
# ...
#   'ukbench03619_hflip.jpg',
#   'ukbench03619_resize.jpg',
#   'ukbench03619_cropped.jpg',
#   'ukbench03619_vflip.jpg'],
#  'ukbench03622.jpg': ['ukbench03622_rotation.jpg',
#   'ukbench03622_hflip.jpg',
#   'ukbench03622_resize.jpg',
#   'ukbench03622_cropped.jpg',
#   'ukbench03622_vflip.jpg'],
#  'ukbench03627.jpg': ['ukbench03627_rotation.jpg',
#   'ukbench03627_hflip.jpg',
#   'ukbench03627_resize.jpg',
#   'ukbench03627_cropped.jpg',
#   'ukbench03627_vflip.jpg'],
#  'ukbench03630.jpg': ['ukbench03630_rotation.jpg',
#   'ukbench03630_hflip.jpg',
#   'ukbench03630_resize.jpg',
#   'ukbench03630_cropped.jpg',
#   'ukbench03630_vflip.jpg'],
#  'ukbench03634.jpg': ['ukbench03634_rotation.jpg',
#   'ukbench03634_hflip.jpg',
#   'ukbench03634_resize.jpg',
#   'ukbench03634_cropped.jpg',
#   'ukbench03634_vflip.jpg'],
#  'ukbench03636.jpg': ['ukbench03636_rotation.jpg',
#   'ukbench03636_hflip.jpg',
#   'ukbench03636_resize.jpg',
#   'ukbench03636_cropped.jpg',
#   'ukbench03636_vflip.jpg'],
#  'ukbench03642.jpg': ['ukbench03642_rotation.jpg',
#   'ukbench03642_hflip.jpg',
#   'ukbench03642_resize.jpg',
#   'ukbench03642_cropped.jpg',
#   'ukbench03642_vflip.jpg'],
#  'ukbench03645.jpg': ['ukbench03645_rotation.jpg',
#   'ukbench03645_hflip.jpg',
#   'ukbench03645_resize.jpg',
#   'ukbench03645_cropped.jpg',
#   'ukbench03645_vflip.jpg'],
#  'ukbench03651.jpg': ['ukbench03651_rotation.jpg',
#   'ukbench03651_hflip.jpg',
#   'ukbench03651_resize.jpg',
#   'ukbench03651_cropped.jpg',
#   'ukbench03651_vflip.jpg'],
#  'ukbench03652.jpg': ['ukbench03652_rotation.jpg',
#   'ukbench03652_hflip.jpg',
#   'ukbench03652_resize.jpg',
#   'ukbench03652_cropped.jpg',
#   'ukbench03652_vflip.jpg'],
#  'ukbench03656.jpg': ['ukbench03656_rotation.jpg',
#   'ukbench03656_hflip.jpg',
#   'ukbench03656_resize.jpg',
#   'ukbench03656_cropped.jpg',
#   'ukbench03656_vflip.jpg'],
#  'ukbench03663.jpg': ['ukbench03663_rotation.jpg',
#   'ukbench03663_hflip.jpg',
#   'ukbench03663_resize.jpg',
#   'ukbench03663_cropped.jpg',
#   'ukbench03663_vflip.jpg'],
#  'ukbench03665.jpg': ['ukbench03665_rotation.jpg',
#   'ukbench03665_hflip.jpg',
#   'ukbench03665_resize.jpg',
#   'ukbench03665_cropped.jpg',
#   'ukbench03665_vflip.jpg'],
#  'ukbench03671.jpg': ['ukbench03671_rotation.jpg',
#   'ukbench03671_hflip.jpg',
#   'ukbench03671_resize.jpg',
#   'ukbench03671_cropped.jpg',
#   'ukbench03671_vflip.jpg'],
#  'ukbench03674.jpg': ['ukbench03674_rotation.jpg',
#   'ukbench03674_hflip.jpg',
#   'ukbench03674_resize.jpg',
#   'ukbench03674_cropped.jpg',
#   'ukbench03674_vflip.jpg'],
#  'ukbench03676.jpg': ['ukbench03676_rotation.jpg',
#   'ukbench03676_hflip.jpg',
#   'ukbench03676_resize.jpg',
#   'ukbench03676_cropped.jpg',
#   'ukbench03676_vflip.jpg'],
#  'ukbench03682.jpg': ['ukbench03682_rotation.jpg',
#   'ukbench03682_hflip.jpg',
#   'ukbench03682_resize.jpg',
#   'ukbench03682_cropped.jpg',
#   'ukbench03682_vflip.jpg'],
#  'ukbench03684.jpg': ['ukbench03684_rotation.jpg',
#   'ukbench03684_hflip.jpg',
#   'ukbench03684_resize.jpg',
#   'ukbench03684_cropped.jpg',
#   'ukbench03684_vflip.jpg'],
#  'ukbench03691.jpg': ['ukbench03691_rotation.jpg',
#   'ukbench03691_hflip.jpg',
#   'ukbench03691_resize.jpg',
#   'ukbench03691_cropped.jpg',
#   'ukbench03691_vflip.jpg'],
#  'ukbench03692.jpg': ['ukbench03692_rotation.jpg',
#   'ukbench03692_hflip.jpg',
#   'ukbench03692_resize.jpg',
#   'ukbench03692_cropped.jpg',
#   'ukbench03692_vflip.jpg'],
#  'ukbench03696.jpg': ['ukbench03696_rotation.jpg',
#   'ukbench03696_hflip.jpg',
#   'ukbench03696_resize.jpg',
#   'ukbench03696_cropped.jpg',
#   'ukbench03696_vflip.jpg'],
#  'ukbench03701.jpg': ['ukbench03701_rotation.jpg',
#   'ukbench03701_hflip.jpg',
#   'ukbench03701_resize.jpg',
#   'ukbench03701_cropped.jpg',
#   'ukbench03701_vflip.jpg'],
#  'ukbench03707.jpg': ['ukbench03707_rotation.jpg',
#   'ukbench03707_hflip.jpg',
#   'ukbench03707_resize.jpg',
#   'ukbench03707_cropped.jpg',
#   'ukbench03707_vflip.jpg'],
#  'ukbench03710.jpg': ['ukbench03710_rotation.jpg',
#   'ukbench03710_hflip.jpg',
#   'ukbench03710_resize.jpg',
#   'ukbench03710_cropped.jpg',
#   'ukbench03710_vflip.jpg'],
#  'ukbench03712.jpg': ['ukbench03712_rotation.jpg',
#   'ukbench03712_hflip.jpg',
#   'ukbench03712_resize.jpg',
#   'ukbench03712_cropped.jpg',
#   'ukbench03712_vflip.jpg'],
#  'ukbench03717.jpg': ['ukbench03717_rotation.jpg',
#   'ukbench03717_hflip.jpg',
#   'ukbench03717_resize.jpg',
#   'ukbench03717_cropped.jpg',
#   'ukbench03717_vflip.jpg'],
#  'ukbench03721.jpg': ['ukbench03721_rotation.jpg',
#   'ukbench03721_hflip.jpg',
#   'ukbench03721_resize.jpg',
#   'ukbench03721_cropped.jpg',
#   'ukbench03721_vflip.jpg'],
#  'ukbench03725.jpg': ['ukbench03725_rotation.jpg',
#   'ukbench03725_hflip.jpg',
#   'ukbench03725_resize.jpg',
#   'ukbench03725_cropped.jpg',
#   'ukbench03725_vflip.jpg'],
#  'ukbench03728.jpg': ['ukbench03728_rotation.jpg',
#   'ukbench03728_hflip.jpg',
#   'ukbench03728_resize.jpg',
#   'ukbench03728_cropped.jpg',
#   'ukbench03728_vflip.jpg'],
#  'ukbench03733.jpg': ['ukbench03733_rotation.jpg',
#   'ukbench03733_hflip.jpg',
#   'ukbench03733_resize.jpg',
#   'ukbench03733_cropped.jpg',
#   'ukbench03733_vflip.jpg'],
#  'ukbench03737.jpg': ['ukbench03737_rotation.jpg',
#   'ukbench03737_hflip.jpg',
#   'ukbench03737_resize.jpg',
#   'ukbench03737_cropped.jpg',
#   'ukbench03737_vflip.jpg'],
#  'ukbench03743.jpg': ['ukbench03743_rotation.jpg',
#   'ukbench03743_hflip.jpg',
#   'ukbench03743_resize.jpg',
#   'ukbench03743_cropped.jpg',
#   'ukbench03743_vflip.jpg'],
#  'ukbench03747.jpg': ['ukbench03747_rotation.jpg',
#   'ukbench03747_hflip.jpg',
#   'ukbench03747_resize.jpg',
#   'ukbench03747_cropped.jpg',
#   'ukbench03747_vflip.jpg'],
#  'ukbench03750.jpg': ['ukbench03750_rotation.jpg',
#   'ukbench03750_hflip.jpg',
#   'ukbench03750_resize.jpg',
#   'ukbench03750_cropped.jpg',
#   'ukbench03750_vflip.jpg'],
#  'ukbench03755.jpg': ['ukbench03755_rotation.jpg',
#   'ukbench03755_hflip.jpg',
#   'ukbench03755_resize.jpg',
#   'ukbench03755_cropped.jpg',
#   'ukbench03755_vflip.jpg'],
#  'ukbench03758.jpg': ['ukbench03758_rotation.jpg',
#   'ukbench03758_hflip.jpg',
#   'ukbench03758_resize.jpg',
#   'ukbench03758_cropped.jpg',
#   'ukbench03758_vflip.jpg'],
#  'ukbench03763.jpg': ['ukbench03763_rotation.jpg',
#   'ukbench03763_hflip.jpg',
#   'ukbench03763_resize.jpg',
#   'ukbench03763_cropped.jpg',
#   'ukbench03763_vflip.jpg'],
#  'ukbench03766.jpg': ['ukbench03766_rotation.jpg',
#   'ukbench03766_hflip.jpg',
#   'ukbench03766_resize.jpg',
#   'ukbench03766_cropped.jpg',
#   'ukbench03766_vflip.jpg'],
#  'ukbench03771.jpg': ['ukbench03771_rotation.jpg',
#   'ukbench03771_hflip.jpg',
#   'ukbench03771_resize.jpg',
#   'ukbench03771_cropped.jpg',
#   'ukbench03771_vflip.jpg'],
#  'ukbench03774.jpg': ['ukbench03774_rotation.jpg',
#   'ukbench03774_hflip.jpg',
#   'ukbench03774_resize.jpg',
#   'ukbench03774_cropped.jpg',
#   'ukbench03774_vflip.jpg'],
#  'ukbench03776.jpg': ['ukbench03776_rotation.jpg',
#   'ukbench03776_hflip.jpg',
#   'ukbench03776_resize.jpg',
#   'ukbench03776_cropped.jpg',
#   'ukbench03776_vflip.jpg'],
#  'ukbench03783.jpg': ['ukbench03783_rotation.jpg',
#   'ukbench03783_hflip.jpg',
#   'ukbench03783_resize.jpg',
#   'ukbench03783_cropped.jpg',
#   'ukbench03783_vflip.jpg'],
#  'ukbench03785.jpg': ['ukbench03785_rotation.jpg',
#   'ukbench03785_hflip.jpg',
#   'ukbench03785_resize.jpg',
#   'ukbench03785_cropped.jpg',
#   'ukbench03785_vflip.jpg'],
#  'ukbench03791.jpg': ['ukbench03791_rotation.jpg',
#   'ukbench03791_hflip.jpg',
#   'ukbench03791_resize.jpg',
#   'ukbench03791_cropped.jpg',
#   'ukbench03791_vflip.jpg'],
#  'ukbench03793.jpg': ['ukbench03793_rotation.jpg',
#   'ukbench03793_hflip.jpg',
#   'ukbench03793_resize.jpg',
#   'ukbench03793_cropped.jpg',
#   'ukbench03793_vflip.jpg'],
#  'ukbench03799.jpg': ['ukbench03799_rotation.jpg',
#   'ukbench03799_hflip.jpg',
#   'ukbench03799_resize.jpg',
#   'ukbench03799_cropped.jpg',
#   'ukbench03799_vflip.jpg'],
#  'ukbench03803.jpg': ['ukbench03803_rotation.jpg',
#   'ukbench03803_hflip.jpg',
#   'ukbench03803_resize.jpg',
#   'ukbench03803_cropped.jpg',
#   'ukbench03803_vflip.jpg'],
#  'ukbench03806.jpg': ['ukbench03806_rotation.jpg',
#   'ukbench03806_hflip.jpg',
#   'ukbench03806_resize.jpg',
#   'ukbench03806_cropped.jpg',
#   'ukbench03806_vflip.jpg'],
#  'ukbench03810.jpg': ['ukbench03810_rotation.jpg',
#   'ukbench03810_hflip.jpg',
#   'ukbench03810_resize.jpg',
#   'ukbench03810_cropped.jpg',
#   'ukbench03810_vflip.jpg'],
#  'ukbench03813.jpg': ['ukbench03813_rotation.jpg',
#   'ukbench03813_hflip.jpg',
#   'ukbench03813_resize.jpg',
#   'ukbench03813_cropped.jpg',
#   'ukbench03813_vflip.jpg'],
#  'ukbench03817.jpg': ['ukbench03817_rotation.jpg',
#   'ukbench03817_hflip.jpg',
#   'ukbench03817_resize.jpg',
#   'ukbench03817_cropped.jpg',
#   'ukbench03817_vflip.jpg'],
#  'ukbench03823.jpg': ['ukbench03823_rotation.jpg',
#   'ukbench03823_hflip.jpg',
#   'ukbench03823_resize.jpg',
#   'ukbench03823_cropped.jpg',
#   'ukbench03823_vflip.jpg'],
#  'ukbench03824.jpg': ['ukbench03824_rotation.jpg',
#   'ukbench03824_hflip.jpg',
#   'ukbench03824_resize.jpg',
#   'ukbench03824_cropped.jpg',
#   'ukbench03824_vflip.jpg'],
#  'ukbench03828.jpg': ['ukbench03828_rotation.jpg',
#   'ukbench03828_hflip.jpg',
#   'ukbench03828_resize.jpg',
#   'ukbench03828_cropped.jpg',
#   'ukbench03828_vflip.jpg'],
#  'ukbench03835.jpg': ['ukbench03835_rotation.jpg',
#   'ukbench03835_hflip.jpg',
#   'ukbench03835_resize.jpg',
#   'ukbench03835_cropped.jpg',
#   'ukbench03835_vflip.jpg'],
#  'ukbench03839.jpg': ['ukbench03839_rotation.jpg',
#   'ukbench03839_hflip.jpg',
#   'ukbench03839_resize.jpg',
#   'ukbench03839_cropped.jpg',
#   'ukbench03839_vflip.jpg'],
#  'ukbench03841.jpg': ['ukbench03841_rotation.jpg',
#   'ukbench03841_hflip.jpg',
#   'ukbench03841_resize.jpg',
#   'ukbench03841_cropped.jpg',
#   'ukbench03841_vflip.jpg'],
#  'ukbench03847.jpg': ['ukbench03847_rotation.jpg',
#   'ukbench03847_hflip.jpg',
#   'ukbench03847_resize.jpg',
#   'ukbench03847_cropped.jpg',
#   'ukbench03847_vflip.jpg'],
#  'ukbench03851.jpg': ['ukbench03851_rotation.jpg',
#   'ukbench03851_hflip.jpg',
#   'ukbench03851_resize.jpg',
#   'ukbench03851_cropped.jpg',
#   'ukbench03851_vflip.jpg'],
#  'ukbench03854.jpg': ['ukbench03854_rotation.jpg',
#   'ukbench03854_hflip.jpg',
#   'ukbench03854_resize.jpg',
#   'ukbench03854_cropped.jpg',
#   'ukbench03854_vflip.jpg'],
#  'ukbench03857.jpg': ['ukbench03857_rotation.jpg',
#   'ukbench03857_hflip.jpg',
#   'ukbench03857_resize.jpg',
#   'ukbench03857_cropped.jpg',
#   'ukbench03857_vflip.jpg'],
#  'ukbench03863.jpg': ['ukbench03863_rotation.jpg',
#   'ukbench03863_hflip.jpg',
#   'ukbench03863_resize.jpg',
#   'ukbench03863_cropped.jpg',
#   'ukbench03863_vflip.jpg'],
#  'ukbench03865.jpg': ['ukbench03865_rotation.jpg',
#   'ukbench03865_hflip.jpg',
#   'ukbench03865_resize.jpg',
#   'ukbench03865_cropped.jpg',
#   'ukbench03865_vflip.jpg'],
#  'ukbench03868.jpg': ['ukbench03868_rotation.jpg',
#   'ukbench03868_hflip.jpg',
#   'ukbench03868_resize.jpg',
#   'ukbench03868_cropped.jpg',
#   'ukbench03868_vflip.jpg'],
#  'ukbench03873.jpg': ['ukbench03873_rotation.jpg',
#   'ukbench03873_hflip.jpg',
#   'ukbench03873_resize.jpg',
#   'ukbench03873_cropped.jpg',
#   'ukbench03873_vflip.jpg'],
#  'ukbench03876.jpg': ['ukbench03876_rotation.jpg',
#   'ukbench03876_hflip.jpg',
#   'ukbench03876_resize.jpg',
#   'ukbench03876_cropped.jpg',
#   'ukbench03876_vflip.jpg'],
#  'ukbench03882.jpg': ['ukbench03882_rotation.jpg',
#   'ukbench03882_hflip.jpg',
#   'ukbench03882_resize.jpg',
#   'ukbench03882_cropped.jpg',
#   'ukbench03882_vflip.jpg'],
#  'ukbench03884.jpg': ['ukbench03884_rotation.jpg',
#   'ukbench03884_hflip.jpg',
#   'ukbench03884_resize.jpg',
#   'ukbench03884_cropped.jpg',
#   'ukbench03884_vflip.jpg'],
#  'ukbench03891.jpg': ['ukbench03891_rotation.jpg',
#   'ukbench03891_hflip.jpg',
#   'ukbench03891_resize.jpg',
#   'ukbench03891_cropped.jpg',
#   'ukbench03891_vflip.jpg'],
#  'ukbench03892.jpg': ['ukbench03892_rotation.jpg',
#   'ukbench03892_hflip.jpg',
#   'ukbench03892_resize.jpg',
#   'ukbench03892_cropped.jpg',
#   'ukbench03892_vflip.jpg'],
#  'ukbench03896.jpg': ['ukbench03896_rotation.jpg',
#   'ukbench03896_hflip.jpg',
#   'ukbench03896_resize.jpg',
#   'ukbench03896_cropped.jpg',
#   'ukbench03896_vflip.jpg'],
#  'ukbench03900.jpg': ['ukbench03900_rotation.jpg',
#   'ukbench03900_hflip.jpg',
#   'ukbench03900_resize.jpg',
#   'ukbench03900_cropped.jpg',
#   'ukbench03900_vflip.jpg'],
#  'ukbench03904.jpg': ['ukbench03904_rotation.jpg',
#   'ukbench03904_hflip.jpg',
#   'ukbench03904_resize.jpg',
#   'ukbench03904_cropped.jpg',
#   'ukbench03904_vflip.jpg'],
#  'ukbench03908.jpg': ['ukbench03908_rotation.jpg',
#   'ukbench03908_hflip.jpg',
#   'ukbench03908_resize.jpg',
#   'ukbench03908_cropped.jpg',
#   'ukbench03908_vflip.jpg'],
#  'ukbench03913.jpg': ['ukbench03913_rotation.jpg',
#   'ukbench03913_hflip.jpg',
#   'ukbench03913_resize.jpg',
#   'ukbench03913_cropped.jpg',
#   'ukbench03913_vflip.jpg'],
#  'ukbench03918.jpg': ['ukbench03918_rotation.jpg',
#   'ukbench03918_hflip.jpg',
#   'ukbench03918_resize.jpg',
#   'ukbench03918_cropped.jpg',
#   'ukbench03918_vflip.jpg'],
#  'ukbench03921.jpg': ['ukbench03921_rotation.jpg',
#   'ukbench03921_hflip.jpg',
#   'ukbench03921_resize.jpg',
#   'ukbench03921_cropped.jpg',
#   'ukbench03921_vflip.jpg'],
#  'ukbench03925.jpg': ['ukbench03925_rotation.jpg',
#   'ukbench03925_hflip.jpg',
#   'ukbench03925_resize.jpg',
#   'ukbench03925_cropped.jpg',
#   'ukbench03925_vflip.jpg'],
#  'ukbench03931.jpg': ['ukbench03931_rotation.jpg',
#   'ukbench03931_hflip.jpg',
#   'ukbench03931_resize.jpg',
#   'ukbench03931_cropped.jpg',
#   'ukbench03931_vflip.jpg'],
#  'ukbench03934.jpg': ['ukbench03934_rotation.jpg',
#   'ukbench03934_hflip.jpg',
#   'ukbench03934_resize.jpg',
#   'ukbench03934_cropped.jpg',
#   'ukbench03934_vflip.jpg'],
#  'ukbench03937.jpg': ['ukbench03937_rotation.jpg',
#   'ukbench03937_hflip.jpg',
#   'ukbench03937_resize.jpg',
#   'ukbench03937_cropped.jpg',
#   'ukbench03937_vflip.jpg'],
#  'ukbench03942.jpg': ['ukbench03942_rotation.jpg',
#   'ukbench03942_hflip.jpg',
#   'ukbench03942_resize.jpg',
#   'ukbench03942_cropped.jpg',
#   'ukbench03942_vflip.jpg'],
#  'ukbench03947.jpg': ['ukbench03947_rotation.jpg',
#   'ukbench03947_hflip.jpg',
#   'ukbench03947_resize.jpg',
#   'ukbench03947_cropped.jpg',
#   'ukbench03947_vflip.jpg'],
#  'ukbench03950.jpg': ['ukbench03950_rotation.jpg',
#   'ukbench03950_hflip.jpg',
#   'ukbench03950_resize.jpg',
#   'ukbench03950_cropped.jpg',
#   'ukbench03950_vflip.jpg'],
#  'ukbench03953.jpg': ['ukbench03953_rotation.jpg',
#   'ukbench03953_hflip.jpg',
#   'ukbench03953_resize.jpg',
#   'ukbench03953_cropped.jpg',
#   'ukbench03953_vflip.jpg'],
#  'ukbench03956.jpg': ['ukbench03956_rotation.jpg',
#   'ukbench03956_hflip.jpg',
#   'ukbench03956_resize.jpg',
#   'ukbench03956_cropped.jpg',
#   'ukbench03956_vflip.jpg'],
#  'ukbench03961.jpg': ['ukbench03961_rotation.jpg',
#   'ukbench03961_hflip.jpg',
#   'ukbench03961_resize.jpg',
#   'ukbench03961_cropped.jpg',
#   'ukbench03961_vflip.jpg'],
#  'ukbench03964.jpg': ['ukbench03964_rotation.jpg',
#   'ukbench03964_hflip.jpg',
#   'ukbench03964_resize.jpg',
#   'ukbench03964_cropped.jpg',
#   'ukbench03964_vflip.jpg'],
#  'ukbench03970.jpg': ['ukbench03970_rotation.jpg',
#   'ukbench03970_hflip.jpg',
#   'ukbench03970_resize.jpg',
#   'ukbench03970_cropped.jpg',
#   'ukbench03970_vflip.jpg'],
#  'ukbench03974.jpg': ['ukbench03974_rotation.jpg',
#   'ukbench03974_hflip.jpg',
#   'ukbench03974_resize.jpg',
#   'ukbench03974_cropped.jpg',
#   'ukbench03974_vflip.jpg'],
#  'ukbench03978.jpg': ['ukbench03978_rotation.jpg',
#   'ukbench03978_hflip.jpg',
#   'ukbench03978_resize.jpg',
#   'ukbench03978_cropped.jpg',
#   'ukbench03978_vflip.jpg'],
#  'ukbench03981.jpg': ['ukbench03981_rotation.jpg',
#   'ukbench03981_hflip.jpg',
#   'ukbench03981_resize.jpg',
#   'ukbench03981_cropped.jpg',
#   'ukbench03981_vflip.jpg'],
#  'ukbench03985.jpg': ['ukbench03985_rotation.jpg',
#   'ukbench03985_hflip.jpg',
#   'ukbench03985_resize.jpg',
#   'ukbench03985_cropped.jpg',
#   'ukbench03985_vflip.jpg'],
#  'ukbench03989.jpg': ['ukbench03989_rotation.jpg',
#   'ukbench03989_hflip.jpg',
#   'ukbench03989_resize.jpg',
#   'ukbench03989_cropped.jpg',
#   'ukbench03989_vflip.jpg'],
#  'ukbench03995.jpg': ['ukbench03995_rotation.jpg',
#   'ukbench03995_hflip.jpg',
#   'ukbench03995_resize.jpg',
#   'ukbench03995_cropped.jpg',
#   'ukbench03995_vflip.jpg'],
#  'ukbench03998.jpg': ['ukbench03998_rotation.jpg',
#   'ukbench03998_hflip.jpg',
#   'ukbench03998_resize.jpg',
#   'ukbench03998_cropped.jpg',
#   'ukbench03998_vflip.jpg'],
#  ...}

# %%
with open('ground_truth_transformed.pkl', 'wb') as f:
    pickle.dump(dict_ground_truth, f)

# %% [markdown]
# # Ground truth for near-duplicate dataset

# %%
path_near_duplicate = path_source
path_target_ND = Path('Near_duplicate_dataset/')

if not os.path.exists(path_target_ND):
    os.makedirs(path_target_ND)

# %%
# file names of all images in a group are consecutive
# get a list of filenames through os.listdir and sort them in a serial fashion
# Pick groups of 4 files and put them in a single group
# Create 4 sets of ground truths such that each image im the group gets to be the query image (we don't know which image
# should be the representative image for the group)

# %%
all_near_dups = sorted(os.listdir(path_near_duplicate))
n_groups = 2550 # Total number of groups in the dataset (complete dataset has 2550 groups for a total of 10,200 images)
splitted_groups = np.array_split(all_near_dups, n_groups)

# %%
# iterate over the splitted_groups and generate 4 ground truth dictionaries

# %%
group_size = 4 # number of duplicates in a group
dicts = {'dict_{}'.format(i):{} for i in range(group_size)}

# %%
def switcher(case):
    case_name = 'dict_{}'.format(case)
    return case_name

# %%
for gr in splitted_groups:
    group_files = list(gr)
    for i in range(len(group_files)):
        key_el = i
        val_els = set(np.arange(group_size)).difference(set([key_el]))
        dict_to_populate = switcher(key_el)
        dicts[dict_to_populate][group_files[key_el]] = [group_files[j] for j in val_els]

# %%
# save the groups

for i in range(group_size):
    print(f'saving dictionary: {i}')
    dict_to_save = dicts['dict_{}'.format(i)] 
    save_name_dict = 'ground_truth_ND_' + str(i) + '.pkl'
    with open(save_name_dict, 'wb') as f:
        pickle.dump(dict_to_save, f)
# Out:
# saving dictionary: 0
# saving dictionary: 1
# saving dictionary: 2
# saving dictionary: 3

# %%
# Iterate over dictionaries and save query and retrievals

for iteration_name, cur_dict in dicts.items():
    # curr_dict has queries as keys, retrievals as value
    # pdb.set_trace()
    queries = cur_dict.keys()
    retrievals = cur_dict.values()
    
    list_query_filenames = list(queries)
    list_retrievals = list(itertools.chain(*list(retrievals)))
    
    # move queries to query directory, retrievals to retirieval directory
    # create a target path name using iteration name, create directories & subdirs (Query and Retrieval) if they don't exit
    target_save_directory = os.path.join(path_target_ND, iteration_name.split('_')[1])
    
    if not os.path.exists(target_save_directory):
        os.mkdir(target_save_directory)
        query_path = os.path.join(target_save_directory, 'Query')
        os.mkdir(query_path)
        retrieval_path = os.path.join(target_save_directory, 'Retrieval')
        os.mkdir(retrieval_path)
    
        for f in list_query_filenames:
            copyfile(os.path.join(path_source, f), os.path.join(query_path, f))

        for f in list_retrievals:
            copyfile(os.path.join(path_source, f), os.path.join(retrieval_path, f))

# %% [markdown]
# # Exact duplicates

# %%
path_target_exact = Path('exact_dataset/')

# %%
dict_exact = {}

# %%
for gr in splitted_groups:
    group_files = list(gr)
    index_to_select = np.random.randint(0, 4)
    i = gr[index_to_select]
    query = i
    retrievals = group_files
    dict_exact[query] = retrievals

# %%
# move the files into correct locations

list_query_exact = list(dict_exact.keys())
list_retrievals_exact = list(itertools.chain(*list(dict_exact.values())))

# %%
len(list_query_exact)
# Out:
# 2550

# %%
len(list_retrievals_exact)
# Out:
# 10200

# %%
if not os.path.exists(path_target_exact):
    os.mkdir(path_target_exact)
    query_path_exact = os.path.join(path_target_exact, 'Query')
    os.mkdir(query_path_exact)
    retrieval_path_exact = os.path.join(path_target_exact, 'Retrieval')
    os.mkdir(retrieval_path_exact)

    for f in list_query_exact:
        copyfile(os.path.join(path_source, f), os.path.join(query_path_exact, f))

    for f in list_retrievals_exact:
        copyfile(os.path.join(path_source, f), os.path.join(retrieval_path_exact, f))

# %%
# modify dictionary such that key = value

for k in dict_exact.keys():
    dict_exact[k] = [k]

# %%
dict_exact
# Out:
# {'ukbench00000.jpg': ['ukbench00000.jpg'],
#  'ukbench00005.jpg': ['ukbench00005.jpg'],
#  'ukbench00010.jpg': ['ukbench00010.jpg'],
#  'ukbench00013.jpg': ['ukbench00013.jpg'],
#  'ukbench00019.jpg': ['ukbench00019.jpg'],
#  'ukbench00023.jpg': ['ukbench00023.jpg'],
#  'ukbench00026.jpg': ['ukbench00026.jpg'],
#  'ukbench00031.jpg': ['ukbench00031.jpg'],
#  'ukbench00034.jpg': ['ukbench00034.jpg'],
#  'ukbench00038.jpg': ['ukbench00038.jpg'],
#  'ukbench00042.jpg': ['ukbench00042.jpg'],
#  'ukbench00046.jpg': ['ukbench00046.jpg'],
#  'ukbench00048.jpg': ['ukbench00048.jpg'],
#  'ukbench00054.jpg': ['ukbench00054.jpg'],
#  'ukbench00057.jpg': ['ukbench00057.jpg'],
#  'ukbench00061.jpg': ['ukbench00061.jpg'],
#  'ukbench00064.jpg': ['ukbench00064.jpg'],
#  'ukbench00070.jpg': ['ukbench00070.jpg'],
#  'ukbench00072.jpg': ['ukbench00072.jpg'],
#  'ukbench00078.jpg': ['ukbench00078.jpg'],
#  'ukbench00081.jpg': ['ukbench00081.jpg'],
#  'ukbench00084.jpg': ['ukbench00084.jpg'],
#  'ukbench00089.jpg': ['ukbench00089.jpg'],
#  'ukbench00094.jpg': ['ukbench00094.jpg'],
#  'ukbench00096.jpg': ['ukbench00096.jpg'],
#  'ukbench00103.jpg': ['ukbench00103.jpg'],
#  'ukbench00105.jpg': ['ukbench00105.jpg'],
#  'ukbench00108.jpg': ['ukbench00108.jpg'],
#  'ukbench00115.jpg': ['ukbench00115.jpg'],
#  'ukbench00119.jpg': ['ukbench00119.jpg'],
#  'ukbench00123.jpg': ['ukbench00123.jpg'],
#  'ukbench00127.jpg': ['ukbench00127.jpg'],
#  'ukbench00131.jpg': ['ukbench00131.jpg'],
#  'ukbench00135.jpg': ['ukbench00135.jpg'],
#  'ukbench00138.jpg': ['ukbench00138.jpg'],
#  'ukbench00143.jpg': ['ukbench00143.jpg'],
#  'ukbench00144.jpg': ['ukbench00144.jpg'],
#  'ukbench00148.jpg': ['ukbench00148.jpg'],
#  'ukbench00153.jpg': ['ukbench00153.jpg'],
#  'ukbench00156.jpg': ['ukbench00156.jpg'],
#  'ukbench00163.jpg': ['ukbench00163.jpg'],
#  'ukbench00167.jpg': ['ukbench00167.jpg'],
#  'ukbench00170.jpg': ['ukbench00170.jpg'],
#  'ukbench00175.jpg': ['ukbench00175.jpg'],
#  'ukbench01880.jpg': ['ukbench01880.jpg'],
#  'ukbench01885.jpg': ['ukbench01885.jpg'],
#  'ukbench01888.jpg': ['ukbench01888.jpg'],
#  'ukbench01895.jpg': ['ukbench01895.jpg'],
#  'ukbench01899.jpg': ['ukbench01899.jpg'],
#  'ukbench01900.jpg': ['ukbench01900.jpg'],
#  'ukbench01904.jpg': ['ukbench01904.jpg'],
#  'ukbench01910.jpg': ['ukbench01910.jpg'],
#  'ukbench01915.jpg': ['ukbench01915.jpg'],
#  'ukbench01918.jpg': ['ukbench01918.jpg'],
#  'ukbench01921.jpg': ['ukbench01921.jpg'],
#  'ukbench01927.jpg': ['ukbench01927.jpg'],
#  'ukbench01928.jpg': ['ukbench01928.jpg'],
#  'ukbench01935.jpg': ['ukbench01935.jpg'],
#  'ukbench01937.jpg': ['ukbench01937.jpg'],
#  'ukbench01942.jpg': ['ukbench01942.jpg'],
#  'ukbench01945.jpg': ['ukbench01945.jpg'],
#  'ukbench01948.jpg': ['ukbench01948.jpg'],
#  'ukbench01955.jpg': ['ukbench01955.jpg'],
#  'ukbench01956.jpg': ['ukbench01956.jpg'],
#  'ukbench01960.jpg': ['ukbench01960.jpg'],
#  'ukbench01967.jpg': ['ukbench01967.jpg'],
#  'ukbench01970.jpg': ['ukbench01970.jpg'],
#  'ukbench01974.jpg': ['ukbench01974.jpg'],
#  'ukbench01978.jpg': ['ukbench01978.jpg'],
#  'ukbench01983.jpg': ['ukbench01983.jpg'],
#  'ukbench01985.jpg': ['ukbench01985.jpg'],
#  'ukbench01989.jpg': ['ukbench01989.jpg'],
#  'ukbench01995.jpg': ['ukbench01995.jpg'],
#  'ukbench01996.jpg': ['ukbench01996.jpg'],
#  'ukbench02003.jpg': ['ukbench02003.jpg'],
#  'ukbench02006.jpg': ['ukbench02006.jpg'],
#  'ukbench02010.jpg': ['ukbench02010.jpg'],
#  'ukbench02014.jpg': ['ukbench02014.jpg'],
#  'ukbench02018.jpg': ['ukbench02018.jpg'],
#  'ukbench02020.jpg': ['ukbench02020.jpg'],
#  'ukbench02025.jpg': ['ukbench02025.jpg'],
#  'ukbench02029.jpg': ['ukbench02029.jpg'],
#  'ukbench02035.jpg': ['ukbench02035.jpg'],
#  'ukbench02039.jpg': ['ukbench02039.jpg'],
#  'ukbench02042.jpg': ['ukbench02042.jpg'],
#  'ukbench02047.jpg': ['ukbench02047.jpg'],
#  'ukbench02049.jpg': ['ukbench02049.jpg'],
#  'ukbench02053.jpg': ['ukbench02053.jpg'],
#  'ukbench02058.jpg': ['ukbench02058.jpg'],
#  'ukbench02060.jpg': ['ukbench02060.jpg'],
#  'ukbench02067.jpg': ['ukbench02067.jpg'],
#  'ukbench02069.jpg': ['ukbench02069.jpg'],
#  'ukbench02075.jpg': ['ukbench02075.jpg'],
#  'ukbench02079.jpg': ['ukbench02079.jpg'],
#  'ukbench02080.jpg': ['ukbench02080.jpg'],
#  'ukbench02087.jpg': ['ukbench02087.jpg'],
#  'ukbench02089.jpg': ['ukbench02089.jpg'],
#  'ukbench02092.jpg': ['ukbench02092.jpg'],
#  'ukbench02097.jpg': ['ukbench02097.jpg'],
#  'ukbench02102.jpg': ['ukbench02102.jpg'],
#  'ukbench02105.jpg': ['ukbench02105.jpg'],
#  'ukbench02110.jpg': ['ukbench02110.jpg'],
#  'ukbench02113.jpg': ['ukbench02113.jpg'],
#  'ukbench02119.jpg': ['ukbench02119.jpg'],
#  'ukbench02120.jpg': ['ukbench02120.jpg'],
#  'ukbench02127.jpg': ['ukbench02127.jpg'],
#  'ukbench02131.jpg': ['ukbench02131.jpg'],
#  'ukbench02132.jpg': ['ukbench02132.jpg'],
#  'ukbench02138.jpg': ['ukbench02138.jpg'],
#  'ukbench02141.jpg': ['ukbench02141.jpg'],
#  'ukbench02145.jpg': ['ukbench02145.jpg'],
#  'ukbench02148.jpg': ['ukbench02148.jpg'],
#  'ukbench02152.jpg': ['ukbench02152.jpg'],
#  'ukbench02156.jpg': ['ukbench02156.jpg'],
#  'ukbench02163.jpg': ['ukbench02163.jpg'],
#  'ukbench02166.jpg': ['ukbench02166.jpg'],
#  'ukbench02171.jpg': ['ukbench02171.jpg'],
#  'ukbench02173.jpg': ['ukbench02173.jpg'],
#  'ukbench02179.jpg': ['ukbench02179.jpg'],
#  'ukbench02183.jpg': ['ukbench02183.jpg'],
#  'ukbench02186.jpg': ['ukbench02186.jpg'],
#  'ukbench02191.jpg': ['ukbench02191.jpg'],
#  'ukbench02193.jpg': ['ukbench02193.jpg'],
#  'ukbench02199.jpg': ['ukbench02199.jpg'],
#  'ukbench02202.jpg': ['ukbench02202.jpg'],
#  'ukbench02207.jpg': ['ukbench02207.jpg'],
#  'ukbench02211.jpg': ['ukbench02211.jpg'],
#  'ukbench02213.jpg': ['ukbench02213.jpg'],
#  'ukbench02217.jpg': ['ukbench02217.jpg'],
#  'ukbench02220.jpg': ['ukbench02220.jpg'],
#  'ukbench02226.jpg': ['ukbench02226.jpg'],
#  'ukbench02229.jpg': ['ukbench02229.jpg'],
#  'ukbench02233.jpg': ['ukbench02233.jpg'],
#  'ukbench02236.jpg': ['ukbench02236.jpg'],
#  'ukbench02240.jpg': ['ukbench02240.jpg'],
#  'ukbench02247.jpg': ['ukbench02247.jpg'],
#  'ukbench02248.jpg': ['ukbench02248.jpg'],
#  'ukbench02254.jpg': ['ukbench02254.jpg'],
#  'ukbench02256.jpg': ['ukbench02256.jpg'],
#  'ukbench02260.jpg': ['ukbench02260.jpg'],
#  'ukbench02266.jpg': ['ukbench02266.jpg'],
#  'ukbench02271.jpg': ['ukbench02271.jpg'],
#  'ukbench02275.jpg': ['ukbench02275.jpg'],
#  'ukbench02276.jpg': ['ukbench02276.jpg'],
#  'ukbench02282.jpg': ['ukbench02282.jpg'],
#  'ukbench02287.jpg': ['ukbench02287.jpg'],
#  'ukbench02291.jpg': ['ukbench02291.jpg'],
#  'ukbench02294.jpg': ['ukbench02294.jpg'],
#  'ukbench02296.jpg': ['ukbench02296.jpg'],
#  'ukbench02303.jpg': ['ukbench02303.jpg'],
#  'ukbench02305.jpg': ['ukbench02305.jpg'],
#  'ukbench02308.jpg': ['ukbench02308.jpg'],
#  'ukbench02314.jpg': ['ukbench02314.jpg'],
#  'ukbench02317.jpg': ['ukbench02317.jpg'],
#  'ukbench02320.jpg': ['ukbench02320.jpg'],
#  'ukbench02327.jpg': ['ukbench02327.jpg'],
#  'ukbench02329.jpg': ['ukbench02329.jpg'],
#  'ukbench02334.jpg': ['ukbench02334.jpg'],
#  'ukbench02339.jpg': ['ukbench02339.jpg'],
#  'ukbench02342.jpg': ['ukbench02342.jpg'],
#  'ukbench02345.jpg': ['ukbench02345.jpg'],
#  'ukbench02350.jpg': ['ukbench02350.jpg'],
#  'ukbench02354.jpg': ['ukbench02354.jpg'],
#  'ukbench02356.jpg': ['ukbench02356.jpg'],
#  'ukbench02363.jpg': ['ukbench02363.jpg'],
#  'ukbench02364.jpg': ['ukbench02364.jpg'],
#  'ukbench02371.jpg': ['ukbench02371.jpg'],
#  'ukbench02374.jpg': ['ukbench02374.jpg'],
#  'ukbench02376.jpg': ['ukbench02376.jpg'],
#  'ukbench02382.jpg': ['ukbench02382.jpg'],
#  'ukbench02386.jpg': ['ukbench02386.jpg'],
#  'ukbench02390.jpg': ['ukbench02390.jpg'],
#  'ukbench02394.jpg': ['ukbench02394.jpg'],
#  'ukbench02398.jpg': ['ukbench02398.jpg'],
#  'ukbench02400.jpg': ['ukbench02400.jpg'],
#  'ukbench02404.jpg': ['ukbench02404.jpg'],
#  'ukbench02410.jpg': ['ukbench02410.jpg'],
#  'ukbench02414.jpg': ['ukbench02414.jpg'],
#  'ukbench02417.jpg': ['ukbench02417.jpg'],
#  'ukbench02422.jpg': ['ukbench02422.jpg'],
#  'ukbench02426.jpg': ['ukbench02426.jpg'],
#  'ukbench02431.jpg': ['ukbench02431.jpg'],
#  'ukbench02434.jpg': ['ukbench02434.jpg'],
#  'ukbench02436.jpg': ['ukbench02436.jpg'],
#  'ukbench02443.jpg': ['ukbench02443.jpg'],
#  'ukbench02446.jpg': ['ukbench02446.jpg'],
#  'ukbench02448.jpg': ['ukbench02448.jpg'],
#  'ukbench02452.jpg': ['ukbench02452.jpg'],
#  'ukbench02458.jpg': ['ukbench02458.jpg'],
#  'ukbench02463.jpg': ['ukbench02463.jpg'],
#  'ukbench02467.jpg': ['ukbench02467.jpg'],
#  'ukbench02468.jpg': ['ukbench02468.jpg'],
#  'ukbench02475.jpg': ['ukbench02475.jpg'],
#  'ukbench02476.jpg': ['ukbench02476.jpg'],
#  'ukbench02481.jpg': ['ukbench02481.jpg'],
#  'ukbench02486.jpg': ['ukbench02486.jpg'],
#  'ukbench02489.jpg': ['ukbench02489.jpg'],
#  'ukbench02494.jpg': ['ukbench02494.jpg'],
#  'ukbench02496.jpg': ['ukbench02496.jpg'],
#  'ukbench02503.jpg': ['ukbench02503.jpg'],
#  'ukbench02504.jpg': ['ukbench02504.jpg'],
#  'ukbench02509.jpg': ['ukbench02509.jpg'],
#  'ukbench02512.jpg': ['ukbench02512.jpg'],
#  'ukbench02733.jpg': ['ukbench02733.jpg'],
#  'ukbench02737.jpg': ['ukbench02737.jpg'],
#  'ukbench02741.jpg': ['ukbench02741.jpg'],
#  'ukbench02747.jpg': ['ukbench02747.jpg'],
#  'ukbench02750.jpg': ['ukbench02750.jpg'],
#  'ukbench02754.jpg': ['ukbench02754.jpg'],
#  'ukbench02756.jpg': ['ukbench02756.jpg'],
#  'ukbench02761.jpg': ['ukbench02761.jpg'],
#  'ukbench02764.jpg': ['ukbench02764.jpg'],
#  'ukbench02768.jpg': ['ukbench02768.jpg'],
#  'ukbench02773.jpg': ['ukbench02773.jpg'],
#  'ukbench02776.jpg': ['ukbench02776.jpg'],
#  'ukbench02780.jpg': ['ukbench02780.jpg'],
#  'ukbench02787.jpg': ['ukbench02787.jpg'],
#  'ukbench02789.jpg': ['ukbench02789.jpg'],
#  'ukbench02795.jpg': ['ukbench02795.jpg'],
#  'ukbench02798.jpg': ['ukbench02798.jpg'],
#  'ukbench02800.jpg': ['ukbench02800.jpg'],
#  'ukbench02806.jpg': ['ukbench02806.jpg'],
#  'ukbench02811.jpg': ['ukbench02811.jpg'],
#  'ukbench02815.jpg': ['ukbench02815.jpg'],
#  'ukbench02819.jpg': ['ukbench02819.jpg'],
#  'ukbench02822.jpg': ['ukbench02822.jpg'],
#  'ukbench02827.jpg': ['ukbench02827.jpg'],
#  'ukbench02830.jpg': ['ukbench02830.jpg'],
#  'ukbench02832.jpg': ['ukbench02832.jpg'],
#  'ukbench02837.jpg': ['ukbench02837.jpg'],
#  'ukbench02842.jpg': ['ukbench02842.jpg'],
#  'ukbench02844.jpg': ['ukbench02844.jpg'],
#  'ukbench02850.jpg': ['ukbench02850.jpg'],
#  'ukbench02852.jpg': ['ukbench02852.jpg'],
#  'ukbench02857.jpg': ['ukbench02857.jpg'],
#  'ukbench02863.jpg': ['ukbench02863.jpg'],
#  'ukbench02864.jpg': ['ukbench02864.jpg'],
#  'ukbench02868.jpg': ['ukbench02868.jpg'],
#  'ukbench02875.jpg': ['ukbench02875.jpg'],
#  'ukbench02879.jpg': ['ukbench02879.jpg'],
#  'ukbench02881.jpg': ['ukbench02881.jpg'],
#  'ukbench02887.jpg': ['ukbench02887.jpg'],
#  'ukbench02888.jpg': ['ukbench02888.jpg'],
#  'ukbench02895.jpg': ['ukbench02895.jpg'],
#  'ukbench02897.jpg': ['ukbench02897.jpg'],
#  'ukbench02903.jpg': ['ukbench02903.jpg'],
#  'ukbench02907.jpg': ['ukbench02907.jpg'],
#  'ukbench02909.jpg': ['ukbench02909.jpg'],
#  'ukbench02914.jpg': ['ukbench02914.jpg'],
#  'ukbench02917.jpg': ['ukbench02917.jpg'],
#  'ukbench02920.jpg': ['ukbench02920.jpg'],
#  'ukbench02925.jpg': ['ukbench02925.jpg'],
#  'ukbench02930.jpg': ['ukbench02930.jpg'],
#  'ukbench02933.jpg': ['ukbench02933.jpg'],
#  'ukbench02938.jpg': ['ukbench02938.jpg'],
#  'ukbench02943.jpg': ['ukbench02943.jpg'],
#  'ukbench02946.jpg': ['ukbench02946.jpg'],
#  'ukbench02950.jpg': ['ukbench02950.jpg'],
#  'ukbench02953.jpg': ['ukbench02953.jpg'],
#  'ukbench02958.jpg': ['ukbench02958.jpg'],
#  'ukbench02962.jpg': ['ukbench02962.jpg'],
#  'ukbench02964.jpg': ['ukbench02964.jpg'],
#  'ukbench02969.jpg': ['ukbench02969.jpg'],
#  'ukbench02975.jpg': ['ukbench02975.jpg'],
#  'ukbench02977.jpg': ['ukbench02977.jpg'],
#  'ukbench02981.jpg': ['ukbench02981.jpg'],
#  'ukbench02986.jpg': ['ukbench02986.jpg'],
#  'ukbench02991.jpg': ['ukbench02991.jpg'],
#  'ukbench02993.jpg': ['ukbench02993.jpg'],
#  'ukbench02997.jpg': ['ukbench02997.jpg'],
#  'ukbench03003.jpg': ['ukbench03003.jpg'],
#  'ukbench03007.jpg': ['ukbench03007.jpg'],
#  'ukbench03010.jpg': ['ukbench03010.jpg'],
#  'ukbench03015.jpg': ['ukbench03015.jpg'],
#  'ukbench03019.jpg': ['ukbench03019.jpg'],
#  'ukbench03021.jpg': ['ukbench03021.jpg'],
#  'ukbench03024.jpg': ['ukbench03024.jpg'],
#  'ukbench03029.jpg': ['ukbench03029.jpg'],
#  'ukbench03032.jpg': ['ukbench03032.jpg'],
#  'ukbench03037.jpg': ['ukbench03037.jpg'],
#  'ukbench03043.jpg': ['ukbench03043.jpg'],
#  'ukbench03044.jpg': ['ukbench03044.jpg'],
#  'ukbench03048.jpg': ['ukbench03048.jpg'],
#  'ukbench03055.jpg': ['ukbench03055.jpg'],
#  'ukbench03056.jpg': ['ukbench03056.jpg'],
#  'ukbench03063.jpg': ['ukbench03063.jpg'],
#  'ukbench03065.jpg': ['ukbench03065.jpg'],
#  'ukbench03068.jpg': ['ukbench03068.jpg'],
#  'ukbench03075.jpg': ['ukbench03075.jpg'],
#  'ukbench03076.jpg': ['ukbench03076.jpg'],
#  'ukbench03081.jpg': ['ukbench03081.jpg'],
#  'ukbench03084.jpg': ['ukbench03084.jpg'],
#  'ukbench03090.jpg': ['ukbench03090.jpg'],
#  'ukbench03095.jpg': ['ukbench03095.jpg'],
#  'ukbench03098.jpg': ['ukbench03098.jpg'],
#  'ukbench03101.jpg': ['ukbench03101.jpg'],
#  'ukbench03106.jpg': ['ukbench03106.jpg'],
#  'ukbench03109.jpg': ['ukbench03109.jpg'],
#  'ukbench03114.jpg': ['ukbench03114.jpg'],
#  'ukbench03118.jpg': ['ukbench03118.jpg'],
#  'ukbench03120.jpg': ['ukbench03120.jpg'],
#  'ukbench03126.jpg': ['ukbench03126.jpg'],
#  'ukbench03131.jpg': ['ukbench03131.jpg'],
#  'ukbench03134.jpg': ['ukbench03134.jpg'],
#  'ukbench03137.jpg': ['ukbench03137.jpg'],
#  'ukbench03140.jpg': ['ukbench03140.jpg'],
#  'ukbench03146.jpg': ['ukbench03146.jpg'],
#  'ukbench03148.jpg': ['ukbench03148.jpg'],
#  'ukbench03153.jpg': ['ukbench03153.jpg'],
#  'ukbench03158.jpg': ['ukbench03158.jpg'],
#  'ukbench03162.jpg': ['ukbench03162.jpg'],
#  'ukbench03166.jpg': ['ukbench03166.jpg'],
#  'ukbench03168.jpg': ['ukbench03168.jpg'],
#  'ukbench03174.jpg': ['ukbench03174.jpg'],
#  'ukbench03176.jpg': ['ukbench03176.jpg'],
#  'ukbench03181.jpg': ['ukbench03181.jpg'],
#  'ukbench03184.jpg': ['ukbench03184.jpg'],
#  'ukbench03191.jpg': ['ukbench03191.jpg'],
#  'ukbench03195.jpg': ['ukbench03195.jpg'],
#  'ukbench03197.jpg': ['ukbench03197.jpg'],
#  'ukbench03203.jpg': ['ukbench03203.jpg'],
#  'ukbench03207.jpg': ['ukbench03207.jpg'],
#  'ukbench03210.jpg': ['ukbench03210.jpg'],
#  'ukbench03215.jpg': ['ukbench03215.jpg'],
#  'ukbench03216.jpg': ['ukbench03216.jpg'],
#  'ukbench03220.jpg': ['ukbench03220.jpg'],
#  'ukbench03226.jpg': ['ukbench03226.jpg'],
#  'ukbench03229.jpg': ['ukbench03229.jpg'],
#  'ukbench03232.jpg': ['ukbench03232.jpg'],
#  'ukbench03239.jpg': ['ukbench03239.jpg'],
#  'ukbench03243.jpg': ['ukbench03243.jpg'],
#  'ukbench03245.jpg': ['ukbench03245.jpg'],
#  'ukbench03251.jpg': ['ukbench03251.jpg'],
#  'ukbench03254.jpg': ['ukbench03254.jpg'],
#  'ukbench03259.jpg': ['ukbench03259.jpg'],
#  'ukbench03261.jpg': ['ukbench03261.jpg'],
#  'ukbench03267.jpg': ['ukbench03267.jpg'],
#  'ukbench03271.jpg': ['ukbench03271.jpg'],
#  'ukbench03275.jpg': ['ukbench03275.jpg'],
#  'ukbench03278.jpg': ['ukbench03278.jpg'],
#  'ukbench03281.jpg': ['ukbench03281.jpg'],
#  'ukbench03287.jpg': ['ukbench03287.jpg'],
#  'ukbench03289.jpg': ['ukbench03289.jpg'],
#  'ukbench03293.jpg': ['ukbench03293.jpg'],
#  'ukbench03297.jpg': ['ukbench03297.jpg'],
#  'ukbench03300.jpg': ['ukbench03300.jpg'],
#  'ukbench03304.jpg': ['ukbench03304.jpg'],
#  'ukbench03311.jpg': ['ukbench03311.jpg'],
#  'ukbench03312.jpg': ['ukbench03312.jpg'],
#  'ukbench03319.jpg': ['ukbench03319.jpg'],
#  'ukbench03322.jpg': ['ukbench03322.jpg'],
#  'ukbench03325.jpg': ['ukbench03325.jpg'],
#  'ukbench03329.jpg': ['ukbench03329.jpg'],
#  'ukbench03335.jpg': ['ukbench03335.jpg'],
#  'ukbench03338.jpg': ['ukbench03338.jpg'],
#  'ukbench03340.jpg': ['ukbench03340.jpg'],
#  'ukbench03346.jpg': ['ukbench03346.jpg'],
#  'ukbench03349.jpg': ['ukbench03349.jpg'],
#  'ukbench03352.jpg': ['ukbench03352.jpg'],
#  'ukbench03358.jpg': ['ukbench03358.jpg'],
#  'ukbench03363.jpg': ['ukbench03363.jpg'],
#  'ukbench03365.jpg': ['ukbench03365.jpg'],
#  'ukbench03371.jpg': ['ukbench03371.jpg'],
#  'ukbench03374.jpg': ['ukbench03374.jpg'],
#  'ukbench03376.jpg': ['ukbench03376.jpg'],
#  'ukbench03380.jpg': ['ukbench03380.jpg'],
#  'ukbench03386.jpg': ['ukbench03386.jpg'],
#  'ukbench03389.jpg': ['ukbench03389.jpg'],
#  'ukbench03394.jpg': ['ukbench03394.jpg'],
#  'ukbench03397.jpg': ['ukbench03397.jpg'],
#  'ukbench03402.jpg': ['ukbench03402.jpg'],
#  'ukbench03405.jpg': ['ukbench03405.jpg'],
#  'ukbench03411.jpg': ['ukbench03411.jpg'],
#  'ukbench03413.jpg': ['ukbench03413.jpg'],
#  'ukbench03416.jpg': ['ukbench03416.jpg'],
#  'ukbench03421.jpg': ['ukbench03421.jpg'],
#  'ukbench03427.jpg': ['ukbench03427.jpg'],
#  'ukbench03430.jpg': ['ukbench03430.jpg'],
#  'ukbench03435.jpg': ['ukbench03435.jpg'],
#  'ukbench03437.jpg': ['ukbench03437.jpg'],
#  'ukbench03442.jpg': ['ukbench03442.jpg'],
#  'ukbench03444.jpg': ['ukbench03444.jpg'],
#  'ukbench03448.jpg': ['ukbench03448.jpg'],
#  'ukbench03455.jpg': ['ukbench03455.jpg'],
#  'ukbench03458.jpg': ['ukbench03458.jpg'],
#  'ukbench03463.jpg': ['ukbench03463.jpg'],
#  'ukbench03466.jpg': ['ukbench03466.jpg'],
#  'ukbench03468.jpg': ['ukbench03468.jpg'],
#  'ukbench03472.jpg': ['ukbench03472.jpg'],
#  'ukbench03479.jpg': ['ukbench03479.jpg'],
#  'ukbench03482.jpg': ['ukbench03482.jpg'],
#  'ukbench03487.jpg': ['ukbench03487.jpg'],
#  'ukbench03491.jpg': ['ukbench03491.jpg'],
#  'ukbench03492.jpg': ['ukbench03492.jpg'],
#  'ukbench03498.jpg': ['ukbench03498.jpg'],
#  'ukbench03503.jpg': ['ukbench03503.jpg'],
#  'ukbench03505.jpg': ['ukbench03505.jpg'],
#  'ukbench03508.jpg': ['ukbench03508.jpg'],
#  'ukbench03512.jpg': ['ukbench03512.jpg'],
#  'ukbench03516.jpg': ['ukbench03516.jpg'],
#  'ukbench03521.jpg': ['ukbench03521.jpg'],
#  'ukbench03527.jpg': ['ukbench03527.jpg'],
#  'ukbench03530.jpg': ['ukbench03530.jpg'],
#  'ukbench03532.jpg': ['ukbench03532.jpg'],
#  'ukbench03538.jpg': ['ukbench03538.jpg'],
#  'ukbench03540.jpg': ['ukbench03540.jpg'],
#  'ukbench03544.jpg': ['ukbench03544.jpg'],
#  'ukbench03550.jpg': ['ukbench03550.jpg'],
#  'ukbench03552.jpg': ['ukbench03552.jpg'],
#  'ukbench03557.jpg': ['ukbench03557.jpg'],
#  'ukbench03560.jpg': ['ukbench03560.jpg'],
#  'ukbench03566.jpg': ['ukbench03566.jpg'],
#  'ukbench03571.jpg': ['ukbench03571.jpg'],
#  'ukbench03575.jpg': ['ukbench03575.jpg'],
#  'ukbench03579.jpg': ['ukbench03579.jpg'],
#  'ukbench03796.jpg': ['ukbench03796.jpg'],
#  'ukbench03800.jpg': ['ukbench03800.jpg'],
#  'ukbench03805.jpg': ['ukbench03805.jpg'],
#  'ukbench03810.jpg': ['ukbench03810.jpg'],
#  'ukbench03814.jpg': ['ukbench03814.jpg'],
#  'ukbench03816.jpg': ['ukbench03816.jpg'],
#  'ukbench03822.jpg': ['ukbench03822.jpg'],
#  'ukbench03827.jpg': ['ukbench03827.jpg'],
#  'ukbench03828.jpg': ['ukbench03828.jpg'],
#  'ukbench03832.jpg': ['ukbench03832.jpg'],
#  'ukbench03839.jpg': ['ukbench03839.jpg'],
#  'ukbench03841.jpg': ['ukbench03841.jpg'],
#  'ukbench03844.jpg': ['ukbench03844.jpg'],
#  'ukbench03851.jpg': ['ukbench03851.jpg'],
#  'ukbench03853.jpg': ['ukbench03853.jpg'],
#  'ukbench03858.jpg': ['ukbench03858.jpg'],
#  'ukbench03860.jpg': ['ukbench03860.jpg'],
#  'ukbench03866.jpg': ['ukbench03866.jpg'],
#  'ukbench03868.jpg': ['ukbench03868.jpg'],
#  'ukbench03873.jpg': ['ukbench03873.jpg'],
#  'ukbench03878.jpg': ['ukbench03878.jpg'],
#  'ukbench03882.jpg': ['ukbench03882.jpg'],
#  'ukbench03885.jpg': ['ukbench03885.jpg'],
#  'ukbench03889.jpg': ['ukbench03889.jpg'],
#  'ukbench03892.jpg': ['ukbench03892.jpg'],
#  'ukbench03896.jpg': ['ukbench03896.jpg'],
#  'ukbench03902.jpg': ['ukbench03902.jpg'],
#  'ukbench03905.jpg': ['ukbench03905.jpg'],
#  'ukbench03910.jpg': ['ukbench03910.jpg'],
#  'ukbench03915.jpg': ['ukbench03915.jpg'],
#  'ukbench03917.jpg': ['ukbench03917.jpg'],
#  'ukbench03921.jpg': ['ukbench03921.jpg'],
#  'ukbench03924.jpg': ['ukbench03924.jpg'],
#  'ukbench03930.jpg': ['ukbench03930.jpg'],
#  'ukbench03934.jpg': ['ukbench03934.jpg'],
#  'ukbench03936.jpg': ['ukbench03936.jpg'],
#  'ukbench03942.jpg': ['ukbench03942.jpg'],
#  'ukbench03945.jpg': ['ukbench03945.jpg'],
#  'ukbench03949.jpg': ['ukbench03949.jpg'],
#  'ukbench03953.jpg': ['ukbench03953.jpg'],
#  'ukbench03959.jpg': ['ukbench03959.jpg'],
#  'ukbench03962.jpg': ['ukbench03962.jpg'],
#  'ukbench03967.jpg': ['ukbench03967.jpg'],
#  'ukbench03970.jpg': ['ukbench03970.jpg'],
#  'ukbench03974.jpg': ['ukbench03974.jpg'],
#  'ukbench03978.jpg': ['ukbench03978.jpg'],
#  'ukbench03982.jpg': ['ukbench03982.jpg'],
#  'ukbench03986.jpg': ['ukbench03986.jpg'],
#  'ukbench03989.jpg': ['ukbench03989.jpg'],
#  'ukbench03994.jpg': ['ukbench03994.jpg'],
#  'ukbench03999.jpg': ['ukbench03999.jpg'],
#  ...}

# %%
with open('ground_truth_exact.pkl', 'wb') as f:
    pickle.dump(dict_exact, f)
